# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np
import cv2

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
NET_MODEL_NO = 0
if NET_MODEL_NO == 0:
    from models_0 import Net
elif NET_MODEL_NO == 1:
    from models_1 import Net
elif NET_MODEL_NO == 2:
    from models_2 import Net
else:
    from models_3 import Net

# Instantiate the Net model
net = Net()
print(net)
# Out:
# Net(
#   (conv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (drop): Dropout(p=0.2, inplace=False)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Sequential(
#     (0): Linear(in_features=6272, out_features=1024, bias=True)
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=1024, out_features=136, bias=True)
#   )
# )

# %%
# Weight initialization from normal distribution
def weights_init_normal(model):
    """
    Applies initial weights to certain layers in a model.
    The weights are taken from a normal distribution with mean = 0, std dev = 0.02.
    :param model: A module or layer in a neural netowork model 
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = model.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    
    # for every Conv2d or ConvTranspose2d in a model
    # - model.weight.data is sampled from a normal distribution with mean = 0 and std_dev = 0.02
    # remark: bias is switched off here in the convolutional layers
    if classname.find('Conv') != -1:
        print('Updating weights for | ' + str(classname))
        #torch.nn.init.normal_(model.weight.data, 0.0, 0.02)
        model.weight.data.normal_(0.0, 0.02)        
        model.bias.data.fill_(0.0)
    
    # for every Linear layer in a model
    # - model.weight.data is sampled from a normal distribution with mean = 0 and std_dev = 0.02
    # - model.bias.data is set to zero
    if classname.find('Linear') != -1:
        print('Updating weights for | ' + str(classname))
        #torch.nn.init.normal_(model.weight.data, 0.0, 0.02)
        model.weight.data.normal_(0.0, 0.02)
        model.bias.data.fill_(0.0)

# Weight initialization using Xavier / Glorot method sampling from a uniform distribution
def weights_init_xavier_uniform(model):
    """
    Applies initial weights to certain layers in a model.
    The weights are filled in using a uniform distribution according to the method described in 
    "Understanding the difficulty of training deep feedforward neural networks" by Glorot, X. 
    and Bengio, Y. (2010). The resulting tensor will have values sampled from a distribution 
    U(−a,a) where a = gain x sqrt(6 / (fan_in+fan_out). Also known as Glorot initialization.
    :param model: A module or layer in a neural netowork model  
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = model.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    
    # for every Conv2d or ConvTranspose2d in a model
    # - model.weight.data are filled in using Xavier Glorot initialization method
    # remark: bias is switched off here in the convolutional layers
    if classname.find('Conv') != -1:
        print('Updating weights for | ' + str(classname))
        nn.init.xavier_uniform_(model.weight.data, 
                               gain=nn.init.calculate_gain('relu')) # elu not supported => use relu
        model.bias.data.fill_(0.0)
    
    # for every Linear layer in a model
    # - model.weight.data are filled in using Xavier Glorot initialization method
    # - model.bias.data is set to zero
    if classname.find('Linear') != -1:
        print('Updating weights for | ' + str(classname))
        if classname.find('leaky_relu') != -1:
            nn.init.xavier_uniform_(model.weight.data,
                                    gain=nn.init.calculate_gain('leaky_relu', 0.01))
        elif classname.find('relu') != -1:
            nn.init.xavier_normal_(model.weight.data,
                                   gain=nn.init.calculate_gain('relu'))
        else:
            nn.init.xavier_normal_(model.weight.data,
                                   gain=1.0)
        model.bias.data.fill_(0.0)

# Weight initialization using Xavier / Glorot method sampling from a normal distribution
def weights_init_xavier_normal(model):
    """
    Applies initial weights to certain layers in a model.
    The weights are filled in using a normal distribution according to the method described in 
    "Understanding the difficulty of training deep feedforward neural networks" by Glorot, X. 
    and Bengio, Y. (2010). The resulting tensor will have values sampled from N(0,std²) where
    std = gain x sqrt(2 / (fan_in+fan_out). Also known as Glorot initialization.
    :param model: A module or layer in a neural netowork model      
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = model.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    
    # for every Conv2d or ConvTranspose2d in a model
    # - model.weight.data are filled in using Xavier Glorot initialization method
    # remark: bias is switched off here in the convolutional layers
    if classname.find('Conv') != -1:
        print('Updating weights for | ' + str(classname))
        nn.init.xavier_normal_(model.weight.data, 
                               gain=nn.init.calculate_gain('relu')) # elu not supported => use relu
        model.bias.data.fill_(0.0)
    
    # for every Linear layer in a model
    # - model.weight.data are filled in using Xavier Glorot initialization method
    # - model.bias.data is set to zero
    if classname.find('Linear') != -1:
        print('Updating weights for | ' + str(classname))
        if classname.find('leaky_relu') != -1:
            nn.init.xavier_normal_(model.weight.data,
                                   gain=nn.init.calculate_gain('leaky_relu', 0.01))
        elif classname.find('relu') != -1:
            nn.init.xavier_normal_(model.weight.data,
                                   gain=nn.init.calculate_gain('relu'))
        else:
            nn.init.xavier_normal_(model.weight.data,
                                   gain=1.0)
        model.bias.data.fill_(0.0)

# %%
# Initialize model weights using one of the below methods (else use pytorch's default method)
# net.apply(weights_init_normal) # normal distribution
# net.apply(weights_init_xavier_uniform) # Xavier/Glorot method with uniform distribution
# net.apply(weights_init_xavier_normal) # Xavier/Glorot method with normal distribution

# %%
# Check if CUDA is available
use_cuda = torch.cuda.is_available()
if use_cuda:
    print('GPU is available => Train on GPU using CUDA.')
    # Move Net model to cuda if GPU is available
    net.cuda()
    print('Net model moved to device.')
else:
    print(' GPU is not available => Train on CPU')
# Out:
# GPU is available => Train on GPU using CUDA.
# Net model moved to device.

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(256),
                                     RandomCrop(224),
                                     Normalize(), # Do NOT apply Normalize() before Rescale() or RandomCrop()!
                                     ToTensor()])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)

# iterate through the transformed dataset and print some stats about the first few samples
print('Number of images in the transformed dataset: ', len(transformed_dataset))
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images in the transformed dataset:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %%
# Split transformed dataset into training and validation set at a ratio 9 : 1
train_length = int(0.9245 * len(transformed_dataset)) # train: 3200 | valid: 262
# train_length = int(0.913 * len(transformed_dataset)) # train: 3160 | valid: 302
valid_length = len(transformed_dataset) - train_length
train_dataset, valid_dataset = torch.utils.data.random_split(transformed_dataset, (train_length, valid_length))

# Print length of training and validation dataset
print('Number of images in off-split training dataset:   {:>4}'.format(train_length))
print('Number of images in off-split validation dataset: {:>4}'.format(valid_length))
# Out:
# Number of images in off-split training dataset:   3200
# Number of images in off-split validation dataset:  262

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training and validation data in batches
batch_size = 16

train_loader = DataLoader(train_dataset, 
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=4)

valid_loader = DataLoader(valid_dataset,
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 16

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # Switch off gradients for efficient prediction
    with torch.no_grad():
        
        # Set model to evaluation mode
        net.eval()
        
        # iterate through the test dataset
        for i, sample in enumerate(test_loader):
            
            # get sample data: images and ground truth keypoints
            images = sample['image']
            key_pts = sample['keypoints']
            
            # convert images to FloatTensors and move to cuda if available
            if use_cuda:
                images = images.type(torch.FloatTensor).cuda()
            else:
                images = images.type(torch.FloatTensor)
            
            # forward pass to get net output
            output_pts = net(images)
            
            # reshape to batch_size x 68 x 2 pts
            output_pts = output_pts.view(output_pts.size()[0], 68, -1)
            
            # Copy images and output_pts tensors back to CPU if they are not there yet
            images = images.cpu()
            output_pts = output_pts.detach().cpu() # remove "requires gradients" by detaching
            
            # break after first image batch is tested
            if i == 0:
                return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, test_gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(test_gt_pts.size())
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 68, 2])
# torch.Size([16, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, test_gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)
        
        # un-transform the image data
        image = test_images[i].data   # get the image from it's wrapper
        image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image
                
        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_key_pts = None
        if test_gt_pts is not None:
            # un-transform the ground truth key_pts data
            ground_truth_key_pts = test_gt_pts[i].data
            ground_truth_key_pts = ground_truth_key_pts.numpy()
            # undo normalization of keypoints
            ground_truth_key_pts = ground_truth_key_pts*50.0+100
                
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_key_pts)
        
        plt.axis('off')
        
    plt.show()
    
# visualize one batch of test images
visualize_output(test_images, test_outputs, test_gt_pts, batch_size=10)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim
from torch.optim import lr_scheduler

# nn.SmoothL1Loss() creates a criterion that uses a squared term if the absolute element-wise error 
# falls below 1 and an L1 term otherwise. It is less sensitive to outliers than the MSELoss and in 
# some cases prevents exploding gradients (e.g. see Fast R-CNN paper by Ross Girshick). Also known 
# as the Huber loss.
criterion = nn.SmoothL1Loss()

# nn.MSELoss() creates a criterion that measures the mean squared error (squared L2 norm) between 
# each element in the input xxx and target yyy.
# criterion = nn.MSELoss()


# Select optimizer
selected_optimizer = 'Adam'
# selected_optimizer = 'SGD' # leads to accumulated keypoint clouds => seems not useful for this task => use Adam

# Create optimizers for the discriminator and generator
if selected_optimizer == 'Adam':
    
    # Optimization parameters for Adam optimizer
    # lr = 5e-2            # learning rate (default: 1e-3)
    # lr = 1e-2            # learning rate (default: 1e-3)
    # lr = 5e-3            # learning rate (default: 1e-3)
    # lr = 2e-3              # learning rate (default: 1e-3)
    lr = 1e-3            # learning rate (default: 1e-3)
    # lr = 5e-4            # learning rate (default: 1e-3)
    # lr = 5e-2            # learning rate (default: 1e-3)
    # lr = 1e-4            # learning rate (default: 1e-3)
    beta1 = 0.5          # lower beta coefficient for computing running averages of gradient and its square (default: 0.9
    beta2 = 0.999        # upper beta coefficient for computing running averages of gradient and its square (default: 0.999)
    eps = 1e-08          # term added to the denominator to improve numerical stability (default: 1e-8)
    #weight_decay = 0.0   # weight decay resp. L2 penalty (default: 0)
    weight_decay = 1e-07 # weight decay resp. L2 penalty (default: 0)
    # weight_decay = 1e-08 # weight decay resp. L2 penalty (default: 0)

    # Create optimizer for the CNN model built from scratch
    optimizer = optim.Adam(net.parameters(), lr, [beta1, beta2], eps, weight_decay)
    
    # Create scheduler for learning rate decay by a factor of 0.5 every x epochs
    # lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=25, gamma=0.5)
    lr_scheduler = None
    
elif selected_optimizer == 'SGD':
    
    # Optimization parameters for stochastic gradient descent (SGD) optimizer
    # lr = 5e-2            # learning rate
    # lr = 1e-2            # learning rate
    # lr = 5e-3            # learning rate
    # lr = 2e-3            # learning rate
    lr = 1e-3            # learning rate
    # lr = 1e-4            # learning rate
    momentum = 0.0       # momentum factor (default: 0.0)
    # momentum = 0.4       # momentum factor (default: 0.0)
    dampening = 0.0      # dampening for momentum (default: 0.0)
    # dampening = 0.1      # dampening for momentum (default: 0.0)
    weight_decay = 0.0   # weight decay resp. L2 penalty (default: 0.0)
    # weight_decay = 1e-7  # weight decay resp. L2 penalty (default: 0.0)
    # weight_decay = 1e-8  # weight decay resp. L2 penalty (default: 0.0)

    # Create optimizer for the CNN model built from scratch
    optimizer = optim.SGD(net.parameters(), lr, momentum, dampening, weight_decay)
    
    # Create scheduler for learning rate decay by a factor of 0.5 every x epochs
    # lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
    lr_scheduler = None

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
## TODO: change the name to something uniqe for each new model
# The best keypoint model will be stored automatically during training upon decrease of validation loss 
# under the below declared directory and model name

# set model directory
model_dir = 'saved_models/'

# set model name
if NET_MODEL_NO == 0:
    # model name for model 0 and minimum validation loss
    model_name_min_loss = 'keypoints_model_0_min_loss.pt'
    # model name for model 1 and last state after training
    model_name_last_state = 'keypoints_model_0_last_state.pt'
elif NET_MODEL_NO == 1:
    # model name for model 1 and minimum validation loss
    model_name_min_loss = 'keypoints_model_1_min_loss.pt'
    # model name for model 1 and last state after training
    model_name_last_state = 'keypoints_model_1_last_state.pt'
elif NET_MODEL_NO == 2:
    # model name for model 2 and minimum validation loss
    model_name_min_loss = 'keypoints_model_2_min_loss.pt'
    # model name for model 2 and last state after training
    model_name_last_state = 'keypoints_model_2_last_state.pt'
else:
    # model name for model 3 and minimum validation loss
    model_name_min_loss = 'keypoints_model_3_min_loss.pt'
    # model name for model 3 and last state after training
    model_name_last_state = 'keypoints_model_3_last_state.pt'

# set model path for minimum validation loss
model_path_min_loss = model_dir + model_name_min_loss

# set model path for last state after all training epochs
model_path_last_state = model_dir + model_name_last_state

# %%
def train_net(n_epochs,
              train_loader,
              valid_loader,
              model,
              optimizer,
              criterion,
              scheduler,
              use_cuda,
              model_path_min_loss,
              model_path_last_state):
    
    # prepare the net model for training
    model.train()
    
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf
    
    # initialize variables to monitor the history of average training and validation loss
    train_loss_history = np.zeros(n_epochs)
    valid_loss_history = np.zeros(n_epochs)
    
    # start training
    print('\nStart training ...\n')
    
    for epoch in range(n_epochs):  # loop over the dataset multiple times
                
        # Initialize average running training and validation loss
        running_train_loss = 0.0
        running_valid_loss = 0.0
        
        #######################
        # train the Net model #
        #######################
        
        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten keypoint array
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to float tensors for regression loss and move to cuda if available
            if use_cuda:
                key_pts = key_pts.type(torch.FloatTensor).cuda()
                images = images.type(torch.FloatTensor).cuda()
            else:
                key_pts = key_pts.type(torch.FloatTensor)
                images = images.type(torch.FloatTensor)
                
            # forward pass to get predicted outputs
            output_pts = model(images)

            # calculate the training loss between predicted and target keypoints
            train_batch_loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients for each new batch
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            train_batch_loss.backward()

            # update the weights
            optimizer.step()
            
            # Adapt optimization parameters (call after optimization step has been performed)
            if scheduler is not None:
                scheduler.step()
            
            # convert current train_batch_loss into a scalar and add it to the avg. running_train_loss, use .item()
            running_train_loss = (running_train_loss * batch_i + train_batch_loss.item()) / (batch_i + 1)
            
            # store the average training loss of the current epoch
            train_loss_history[epoch] = running_train_loss
            
            # print training loss statistics
            if batch_i % 10 == 9:    # print training loss every 10 batches
                print('Epoch: {}, Batch: {}, Avg. Training Loss: {}'.format(epoch + 1, 
                                                                            batch_i+1, 
                                                                            running_train_loss))
            
        ##########################    
        # validate the Net model #
        ##########################
        
        # set net model to evaluation mode
        model.eval()
        
        # validate on batches of data, assumes you already have valid loader
        for batch_i, data in enumerate(valid_loader):
            
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten keypoint array
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to float tensors for regression loss and move to cuda if available
            if use_cuda:
                key_pts = key_pts.type(torch.FloatTensor).cuda()
                images = images.type(torch.FloatTensor).cuda()
            else:
                key_pts = key_pts.type(torch.FloatTensor)
                images = images.type(torch.FloatTensor)
            
            # forward pass to get predicted outputs
            output_pts = model(images)

            # calculate the validation batch loss between predicted and target keypoints
            valid_batch_loss = criterion(output_pts, key_pts)
            
            # convert current valid_batch_loss into a scalar and add it to the avg. running_valid_loss, use .item()
            running_valid_loss = (running_valid_loss * batch_i + valid_batch_loss.item()) / (batch_i + 1)
            
            # store the average validation loss of the current epoch
            valid_loss_history[epoch] = running_valid_loss
            
            # print validation loss statistics
            if batch_i % 10 == 9:    # print validation loss every 10 batches
                print('Epoch: {}, Batch: {}, Avg. Validation Loss: {}'.format(epoch + 1, 
                                                                              batch_i+1, 
                                                                              running_valid_loss))
            
        # print training and validation loss statistics per epoch
        print('\nEpoch: {}, Avg. Training Loss: {} Avg. Validation Loss: {}\n'.format(epoch + 1, 
                                                                                    running_train_loss, 
                                                                                    running_valid_loss))
        
        ## TODO: save the net if validation loss has decreased
        if running_valid_loss <= valid_loss_min:
            print('\tValidation loss decreased ({:.6f} --> {:.6f}).  Saving net ...\n'.format(
                valid_loss_min,
                running_valid_loss))
            # save the net model parameters with minimum validation loss as state dictionary under the given path
            torch.save(model.state_dict(), model_path_min_loss)
            # Update minimum validation loss achieved so far
            valid_loss_min = running_valid_loss
        
        # set net model back to training mode
        model.eval()
    
    # Print final message upon finishing training process
    print('\n... training finished.\n')
    
    # save the net model parameter of last state of the training process as state directory under the given path
    print('\tMinimum validation loss so far: {:.6f}.\n'.format(valid_loss_min))
    print('\tValidation loss of last state: {:.6f}.  Saving net ...\n'.format(running_valid_loss))
    torch.save(model.state_dict(), model_path_last_state)
    
    # Return the last state of trained net model plus training and validation loss history
    return model, train_loss_history, valid_loss_history

# %%
import time

# number of training epochs
n_epochs = 100 # start small, and increase when you've decided on your model structure and hyperparams

# start timer
start_time = time.time()

# train the cnn model
net, train_loss_history, valid_loss_history = train_net(n_epochs,
                                                        train_loader,
                                                        valid_loader,
                                                        net,
                                                        optimizer,
                                                        criterion,
                                                        lr_scheduler,
                                                        use_cuda,
                                                        model_path_min_loss,
                                                        model_path_last_state)

# get stop time
stop_time = time.time()

# evaluate elapsed time
elapsed_time = stop_time - start_time
print('\tElapsed time: {:.0f} h {:.0f} min {:.0f} s\n'.format(elapsed_time//3600, 
                                                            (elapsed_time%3600)//60,
                                                            (elapsed_time%3600)%60))
# Out:
# Start training ...
#
# Epoch: 1, Batch: 10, Avg. Training Loss: 0.19659657776355743
# Epoch: 1, Batch: 20, Avg. Training Loss: 0.18259358927607536
# Epoch: 1, Batch: 30, Avg. Training Loss: 0.1670060023665428
# Epoch: 1, Batch: 40, Avg. Training Loss: 0.15715516712516545
# Epoch: 1, Batch: 50, Avg. Training Loss: 0.15172990664839742
# Epoch: 1, Batch: 60, Avg. Training Loss: 0.14515810447434585
# Epoch: 1, Batch: 70, Avg. Training Loss: 0.1390139117836952
# Epoch: 1, Batch: 80, Avg. Training Loss: 0.1379361875355244
# Epoch: 1, Batch: 90, Avg. Training Loss: 0.13670798523558514
# Epoch: 1, Batch: 100, Avg. Training Loss: 0.13435659565031532
# Epoch: 1, Batch: 110, Avg. Training Loss: 0.1306981106373397
# Epoch: 1, Batch: 120, Avg. Training Loss: 0.12871964915345113
# Epoch: 1, Batch: 130, Avg. Training Loss: 0.1272014376635735
# Epoch: 1, Batch: 140, Avg. Training Loss: 0.12412597467856752
# Epoch: 1, Batch: 150, Avg. Training Loss: 0.12242540650069718
# Epoch: 1, Batch: 160, Avg. Training Loss: 0.12020973900798712
# Epoch: 1, Batch: 170, Avg. Training Loss: 0.11828004522796944
# Epoch: 1, Batch: 180, Avg. Training Loss: 0.11673211149043511
# Epoch: 1, Batch: 190, Avg. Training Loss: 0.11548285782337192
# Epoch: 1, Batch: 200, Avg. Training Loss: 0.11480025200173262
# Epoch: 1, Batch: 10, Avg. Validation Loss: 0.06187423206865787
#
# Epoch: 1, Avg. Training Loss: 0.11480025200173262 Avg. Validation Loss: 0.06513991820461609
#
# 	Validation loss decreased (inf --> 0.065140).  Saving net ...
#
# Epoch: 2, Batch: 10, Avg. Training Loss: 0.2387465715408325
# Epoch: 2, Batch: 20, Avg. Training Loss: 0.16545191053301095
# Epoch: 2, Batch: 30, Avg. Training Loss: 0.1366942851493756
# Epoch: 2, Batch: 40, Avg. Training Loss: 0.1179747392423451
# Epoch: 2, Batch: 50, Avg. Training Loss: 0.10512983649969102
# Epoch: 2, Batch: 60, Avg. Training Loss: 0.09868779014796018
# Epoch: 2, Batch: 70, Avg. Training Loss: 0.09297568228627955
# Epoch: 2, Batch: 80, Avg. Training Loss: 0.08944841017946599
# Epoch: 2, Batch: 90, Avg. Training Loss: 0.08614909793767661
# Epoch: 2, Batch: 100, Avg. Training Loss: 0.08253620756790038
# Epoch: 2, Batch: 110, Avg. Training Loss: 0.07910309071567923
# Epoch: 2, Batch: 120, Avg. Training Loss: 0.0755428824263314
# Epoch: 2, Batch: 130, Avg. Training Loss: 0.07584065943956372
# Epoch: 2, Batch: 140, Avg. Training Loss: 0.07302147209910405
# Epoch: 2, Batch: 150, Avg. Training Loss: 0.07222813321898376
# Epoch: 2, Batch: 160, Avg. Training Loss: 0.07028160843765358
# Epoch: 2, Batch: 170, Avg. Training Loss: 0.06909172637935944
# Epoch: 2, Batch: 180, Avg. Training Loss: 0.0680538813790513
# Epoch: 2, Batch: 190, Avg. Training Loss: 0.06684422471413483
# Epoch: 2, Batch: 200, Avg. Training Loss: 0.06489116864278907
# Epoch: 2, Batch: 10, Avg. Validation Loss: 0.0296356787905097
#
# Epoch: 2, Avg. Training Loss: 0.06489116864278907 Avg. Validation Loss: 0.029362850439022564
#
# 	Validation loss decreased (0.065140 --> 0.029363).  Saving net ...
#
# Epoch: 3, Batch: 10, Avg. Training Loss: 0.03849960211664438
# Epoch: 3, Batch: 20, Avg. Training Loss: 0.04318522149696946
# Epoch: 3, Batch: 30, Avg. Training Loss: 0.04036536657561859
# Epoch: 3, Batch: 40, Avg. Training Loss: 0.03749059145338833
# Epoch: 3, Batch: 50, Avg. Training Loss: 0.036659696325659755
# Epoch: 3, Batch: 60, Avg. Training Loss: 0.03564699003472925
# Epoch: 3, Batch: 70, Avg. Training Loss: 0.03530974837818316
# Epoch: 3, Batch: 80, Avg. Training Loss: 0.03544983081519604
# Epoch: 3, Batch: 90, Avg. Training Loss: 0.03554726865970426
# Epoch: 3, Batch: 100, Avg. Training Loss: 0.03575281148776412
# Epoch: 3, Batch: 110, Avg. Training Loss: 0.035812615044415
# Epoch: 3, Batch: 120, Avg. Training Loss: 0.03538432012622555
# Epoch: 3, Batch: 130, Avg. Training Loss: 0.03486459690074508
# Epoch: 3, Batch: 140, Avg. Training Loss: 0.034133562385769825
# Epoch: 3, Batch: 150, Avg. Training Loss: 0.03377131192634503
# Epoch: 3, Batch: 160, Avg. Training Loss: 0.03375018744845874
# Epoch: 3, Batch: 170, Avg. Training Loss: 0.03335671241340391
# Epoch: 3, Batch: 180, Avg. Training Loss: 0.033194682100373844
# Epoch: 3, Batch: 190, Avg. Training Loss: 0.0327020563283249
# Epoch: 3, Batch: 200, Avg. Training Loss: 0.03241446086205544
# Epoch: 3, Batch: 10, Avg. Validation Loss: 0.02366130696609616
#
# Epoch: 3, Avg. Training Loss: 0.03241446086205544 Avg. Validation Loss: 0.02503605028066565
#
# 	Validation loss decreased (0.029363 --> 0.025036).  Saving net ...
#
# Epoch: 4, Batch: 10, Avg. Training Loss: 0.027497484534978866
# Epoch: 4, Batch: 20, Avg. Training Loss: 0.02423418643884361
# Epoch: 4, Batch: 30, Avg. Training Loss: 0.02415921747063597
# Epoch: 4, Batch: 40, Avg. Training Loss: 0.027247711620293557
# Epoch: 4, Batch: 50, Avg. Training Loss: 0.02905418386682868
# Epoch: 4, Batch: 60, Avg. Training Loss: 0.029257450827086966
# Epoch: 4, Batch: 70, Avg. Training Loss: 0.0305656290879207
# Epoch: 4, Batch: 80, Avg. Training Loss: 0.030223931663203984
# Epoch: 4, Batch: 90, Avg. Training Loss: 0.03076273122181495
# Epoch: 4, Batch: 100, Avg. Training Loss: 0.030789988590404393
# Epoch: 4, Batch: 110, Avg. Training Loss: 0.03242967527529056
# Epoch: 4, Batch: 120, Avg. Training Loss: 0.031623947100403414
# Epoch: 4, Batch: 130, Avg. Training Loss: 0.03219800264073106
# Epoch: 4, Batch: 140, Avg. Training Loss: 0.031657429112653644
# Epoch: 4, Batch: 150, Avg. Training Loss: 0.03153456834455331
# Epoch: 4, Batch: 160, Avg. Training Loss: 0.03147079151822253
# Epoch: 4, Batch: 170, Avg. Training Loss: 0.03135081382249206
# Epoch: 4, Batch: 180, Avg. Training Loss: 0.03170276781440608
# Epoch: 4, Batch: 190, Avg. Training Loss: 0.03142954491470989
# Epoch: 4, Batch: 200, Avg. Training Loss: 0.030939384950324885
# Epoch: 4, Batch: 10, Avg. Validation Loss: 0.026878486573696136
#
# Epoch: 4, Avg. Training Loss: 0.030939384950324885 Avg. Validation Loss: 0.026001202435616183
#
# Epoch: 5, Batch: 10, Avg. Training Loss: 0.019950866885483264
# Epoch: 5, Batch: 20, Avg. Training Loss: 0.021700995555147533
# Epoch: 5, Batch: 30, Avg. Training Loss: 0.023799270174155635
# Epoch: 5, Batch: 40, Avg. Training Loss: 0.024731757980771363
# Epoch: 5, Batch: 50, Avg. Training Loss: 0.024571062438189982
# Epoch: 5, Batch: 60, Avg. Training Loss: 0.024248137278482317
# Epoch: 5, Batch: 70, Avg. Training Loss: 0.02377338877746037
# Epoch: 5, Batch: 80, Avg. Training Loss: 0.02432890413329005
# Epoch: 5, Batch: 90, Avg. Training Loss: 0.024524327222671775
# Epoch: 5, Batch: 100, Avg. Training Loss: 0.024029003530740736
# Epoch: 5, Batch: 110, Avg. Training Loss: 0.02442297599363056
# Epoch: 5, Batch: 120, Avg. Training Loss: 0.024380220371919375
# Epoch: 5, Batch: 130, Avg. Training Loss: 0.02391875394834922
# Epoch: 5, Batch: 140, Avg. Training Loss: 0.023735575444464172
# Epoch: 5, Batch: 150, Avg. Training Loss: 0.023657983541488646
# Epoch: 5, Batch: 160, Avg. Training Loss: 0.023324416298419238
# Epoch: 5, Batch: 170, Avg. Training Loss: 0.023610633135061055
# Epoch: 5, Batch: 180, Avg. Training Loss: 0.024024255470269255
# Epoch: 5, Batch: 190, Avg. Training Loss: 0.02391264620972307
# Epoch: 5, Batch: 200, Avg. Training Loss: 0.02394867376424372
# Epoch: 5, Batch: 10, Avg. Validation Loss: 0.03385914377868175
#
# Epoch: 5, Avg. Training Loss: 0.02394867376424372 Avg. Validation Loss: 0.02778723058016861
#
# Epoch: 6, Batch: 10, Avg. Training Loss: 0.027949704602360726
# Epoch: 6, Batch: 20, Avg. Training Loss: 0.02385414461605251
# Epoch: 6, Batch: 30, Avg. Training Loss: 0.021473021215448775
# Epoch: 6, Batch: 40, Avg. Training Loss: 0.02062397203408181
# Epoch: 6, Batch: 50, Avg. Training Loss: 0.019613699726760383
# Epoch: 6, Batch: 60, Avg. Training Loss: 0.020164031488820906
# Epoch: 6, Batch: 70, Avg. Training Loss: 0.020559177574302465
# Epoch: 6, Batch: 80, Avg. Training Loss: 0.020106712286360556
# Epoch: 6, Batch: 90, Avg. Training Loss: 0.019463663103265888
# Epoch: 6, Batch: 100, Avg. Training Loss: 0.020981562715023747
# Epoch: 6, Batch: 110, Avg. Training Loss: 0.020628126947717224
# Epoch: 6, Batch: 120, Avg. Training Loss: 0.020892450531634185
# Epoch: 6, Batch: 130, Avg. Training Loss: 0.02054091530063977
# Epoch: 6, Batch: 140, Avg. Training Loss: 0.020462356095335307
# Epoch: 6, Batch: 150, Avg. Training Loss: 0.020429697011907888
# Epoch: 6, Batch: 160, Avg. Training Loss: 0.02015423348639159
# Epoch: 6, Batch: 170, Avg. Training Loss: 0.019947008761193808
# Epoch: 6, Batch: 180, Avg. Training Loss: 0.0199241033134361
# Epoch: 6, Batch: 190, Avg. Training Loss: 0.020806643611898542
# Epoch: 6, Batch: 200, Avg. Training Loss: 0.020675822817720468
# Epoch: 6, Batch: 10, Avg. Validation Loss: 0.022536393813788892
#
# Epoch: 6, Avg. Training Loss: 0.020675822817720468 Avg. Validation Loss: 0.021210654474356595
#
# 	Validation loss decreased (0.025036 --> 0.021211).  Saving net ...
#
# Epoch: 7, Batch: 10, Avg. Training Loss: 0.017954877577722073
# Epoch: 7, Batch: 20, Avg. Training Loss: 0.021185861062258483
# Epoch: 7, Batch: 30, Avg. Training Loss: 0.026609446356693902
# Epoch: 7, Batch: 40, Avg. Training Loss: 0.02378187973517924
# Epoch: 7, Batch: 50, Avg. Training Loss: 0.02251800091937184
# Epoch: 7, Batch: 60, Avg. Training Loss: 0.023832831966380273
# Epoch: 7, Batch: 70, Avg. Training Loss: 0.022863618736820558
# Epoch: 7, Batch: 80, Avg. Training Loss: 0.024019658064935355
# Epoch: 7, Batch: 90, Avg. Training Loss: 0.02330696555889315
# Epoch: 7, Batch: 100, Avg. Training Loss: 0.022534635327756406
# Epoch: 7, Batch: 110, Avg. Training Loss: 0.021787410237911073
# Epoch: 7, Batch: 120, Avg. Training Loss: 0.021095874455446997
# Epoch: 7, Batch: 130, Avg. Training Loss: 0.02077424218161748
# Epoch: 7, Batch: 140, Avg. Training Loss: 0.020155971889783224
# Epoch: 7, Batch: 150, Avg. Training Loss: 0.019953702439864475
# Epoch: 7, Batch: 160, Avg. Training Loss: 0.019743792380904776
# Epoch: 7, Batch: 170, Avg. Training Loss: 0.01934665428364978
# Epoch: 7, Batch: 180, Avg. Training Loss: 0.019984515326925446
# Epoch: 7, Batch: 190, Avg. Training Loss: 0.02003129586381347
# Epoch: 7, Batch: 200, Avg. Training Loss: 0.02007732884492724
# Epoch: 7, Batch: 10, Avg. Validation Loss: 0.014298788737505674
#
# Epoch: 7, Avg. Training Loss: 0.02007732884492724 Avg. Validation Loss: 0.020954319933319792
#
# 	Validation loss decreased (0.021211 --> 0.020954).  Saving net ...
#
# Epoch: 8, Batch: 10, Avg. Training Loss: 0.012870759097859263
# Epoch: 8, Batch: 20, Avg. Training Loss: 0.015535755129531027
# Epoch: 8, Batch: 30, Avg. Training Loss: 0.01521646169324716
# Epoch: 8, Batch: 40, Avg. Training Loss: 0.015931747539434583
# Epoch: 8, Batch: 50, Avg. Training Loss: 0.01626436371356249
# Epoch: 8, Batch: 60, Avg. Training Loss: 0.01661303948300581
# Epoch: 8, Batch: 70, Avg. Training Loss: 0.016372716174061816
# Epoch: 8, Batch: 80, Avg. Training Loss: 0.016018118732608857
# Epoch: 8, Batch: 90, Avg. Training Loss: 0.015955849317833778
# Epoch: 8, Batch: 100, Avg. Training Loss: 0.016181534384377295
# Epoch: 8, Batch: 110, Avg. Training Loss: 0.01723107000050896
# Epoch: 8, Batch: 120, Avg. Training Loss: 0.01732483887656901
# Epoch: 8, Batch: 130, Avg. Training Loss: 0.017225707540861678
# Epoch: 8, Batch: 140, Avg. Training Loss: 0.016779865148211157
# Epoch: 8, Batch: 150, Avg. Training Loss: 0.0170173939038068
# Epoch: 8, Batch: 160, Avg. Training Loss: 0.017083831570926113
# Epoch: 8, Batch: 170, Avg. Training Loss: 0.01679913561845964
# Epoch: 8, Batch: 180, Avg. Training Loss: 0.017540310527611926
# Epoch: 8, Batch: 190, Avg. Training Loss: 0.01777082836794617
# Epoch: 8, Batch: 200, Avg. Training Loss: 0.018169129549060012
# Epoch: 8, Batch: 10, Avg. Validation Loss: 0.013507444970309734
#
# Epoch: 8, Avg. Training Loss: 0.018169129549060012 Avg. Validation Loss: 0.01879033021738424
#
# 	Validation loss decreased (0.020954 --> 0.018790).  Saving net ...
#
# Epoch: 9, Batch: 10, Avg. Training Loss: 0.013691556733101606
# Epoch: 9, Batch: 20, Avg. Training Loss: 0.015128138312138616
# Epoch: 9, Batch: 30, Avg. Training Loss: 0.01607031303768357
# Epoch: 9, Batch: 40, Avg. Training Loss: 0.016041158058214933
# Epoch: 9, Batch: 50, Avg. Training Loss: 0.016753209037706253
# Epoch: 9, Batch: 60, Avg. Training Loss: 0.018587422844332954
# Epoch: 9, Batch: 70, Avg. Training Loss: 0.018172205006703735
# Epoch: 9, Batch: 80, Avg. Training Loss: 0.01883041264372878
# Epoch: 9, Batch: 90, Avg. Training Loss: 0.019744758592504595
# Epoch: 9, Batch: 100, Avg. Training Loss: 0.019611362447030843
# Epoch: 9, Batch: 110, Avg. Training Loss: 0.020545982556756246
# Epoch: 9, Batch: 120, Avg. Training Loss: 0.02097773674177006
# Epoch: 9, Batch: 130, Avg. Training Loss: 0.02052734773606062
# Epoch: 9, Batch: 140, Avg. Training Loss: 0.020454903193084257
# Epoch: 9, Batch: 150, Avg. Training Loss: 0.02066015383849541
# Epoch: 9, Batch: 160, Avg. Training Loss: 0.020454025175422427
# Epoch: 9, Batch: 170, Avg. Training Loss: 0.02021126298453001
# Epoch: 9, Batch: 180, Avg. Training Loss: 0.0199428680844398
# Epoch: 9, Batch: 190, Avg. Training Loss: 0.019670249357525448
# Epoch: 9, Batch: 200, Avg. Training Loss: 0.020130130785983056
# Epoch: 9, Batch: 10, Avg. Validation Loss: 0.02164137754589319
#
# Epoch: 9, Avg. Training Loss: 0.020130130785983056 Avg. Validation Loss: 0.020902390756151256
#
# Epoch: 10, Batch: 10, Avg. Training Loss: 0.013472939655184746
# Epoch: 10, Batch: 20, Avg. Training Loss: 0.012963867955841124
# Epoch: 10, Batch: 30, Avg. Training Loss: 0.012222115850696961
# Epoch: 10, Batch: 40, Avg. Training Loss: 0.01224192783702165
# Epoch: 10, Batch: 50, Avg. Training Loss: 0.012292123567312956
# Epoch: 10, Batch: 60, Avg. Training Loss: 0.012404183275066316
# Epoch: 10, Batch: 70, Avg. Training Loss: 0.013092879465382014
# Epoch: 10, Batch: 80, Avg. Training Loss: 0.01283247628598474
# Epoch: 10, Batch: 90, Avg. Training Loss: 0.01427074503670964
# Epoch: 10, Batch: 100, Avg. Training Loss: 0.014601454543881119
# Epoch: 10, Batch: 110, Avg. Training Loss: 0.016058703854849393
# Epoch: 10, Batch: 120, Avg. Training Loss: 0.015962711271519468
# Epoch: 10, Batch: 130, Avg. Training Loss: 0.017009806826424147
# Epoch: 10, Batch: 140, Avg. Training Loss: 0.016870850580744452
# Epoch: 10, Batch: 150, Avg. Training Loss: 0.016715135139723628
# Epoch: 10, Batch: 160, Avg. Training Loss: 0.016501576604787266
# Epoch: 10, Batch: 170, Avg. Training Loss: 0.01633593271596029
# Epoch: 10, Batch: 180, Avg. Training Loss: 0.01616718184668571
# Epoch: 10, Batch: 190, Avg. Training Loss: 0.01602580908342804
# Epoch: 10, Batch: 200, Avg. Training Loss: 0.015895537289325152
# Epoch: 10, Batch: 10, Avg. Validation Loss: 0.025453340355306865
#
# Epoch: 10, Avg. Training Loss: 0.015895537289325152 Avg. Validation Loss: 0.019907625501646715
#
# Epoch: 11, Batch: 10, Avg. Training Loss: 0.011278801644220949
# Epoch: 11, Batch: 20, Avg. Training Loss: 0.013659070781432091
# Epoch: 11, Batch: 30, Avg. Training Loss: 0.016254704740519325
# Epoch: 11, Batch: 40, Avg. Training Loss: 0.016732076869811863
# Epoch: 11, Batch: 50, Avg. Training Loss: 0.016119513465091592
# Epoch: 11, Batch: 60, Avg. Training Loss: 0.01585572386781376
# Epoch: 11, Batch: 70, Avg. Training Loss: 0.015154511820791037
# Epoch: 11, Batch: 80, Avg. Training Loss: 0.015631400194251917
# Epoch: 11, Batch: 90, Avg. Training Loss: 0.015911041215683028
# Epoch: 11, Batch: 100, Avg. Training Loss: 0.01612778629641981
# Epoch: 11, Batch: 110, Avg. Training Loss: 0.017806767845865008
# Epoch: 11, Batch: 120, Avg. Training Loss: 0.018348085845354953
# Epoch: 11, Batch: 130, Avg. Training Loss: 0.018777665399158237
# Epoch: 11, Batch: 140, Avg. Training Loss: 0.018434659800758327
# Epoch: 11, Batch: 150, Avg. Training Loss: 0.01892465877346695
# Epoch: 11, Batch: 160, Avg. Training Loss: 0.018631647396250634
# Epoch: 11, Batch: 170, Avg. Training Loss: 0.018333968429771412
# Epoch: 11, Batch: 180, Avg. Training Loss: 0.018886465473204026
# Epoch: 11, Batch: 190, Avg. Training Loss: 0.01855165494949018
# Epoch: 11, Batch: 200, Avg. Training Loss: 0.018367083047050987
# Epoch: 11, Batch: 10, Avg. Validation Loss: 0.021513093449175357
#
# Epoch: 11, Avg. Training Loss: 0.018367083047050987 Avg. Validation Loss: 0.01928976715049323
#
# Epoch: 12, Batch: 10, Avg. Training Loss: 0.02619641087949276
# Epoch: 12, Batch: 20, Avg. Training Loss: 0.018802934465929864
# Epoch: 12, Batch: 30, Avg. Training Loss: 0.016506650438532233
# Epoch: 12, Batch: 40, Avg. Training Loss: 0.01661797162378207
# Epoch: 12, Batch: 50, Avg. Training Loss: 0.0160770414955914
# Epoch: 12, Batch: 60, Avg. Training Loss: 0.018211915949359538
# Epoch: 12, Batch: 70, Avg. Training Loss: 0.0177706682389336
# Epoch: 12, Batch: 80, Avg. Training Loss: 0.017498868063557892
# Epoch: 12, Batch: 90, Avg. Training Loss: 0.016831924176464477
# Epoch: 12, Batch: 100, Avg. Training Loss: 0.01640812421217561
# Epoch: 12, Batch: 110, Avg. Training Loss: 0.016557332873344426
# Epoch: 12, Batch: 120, Avg. Training Loss: 0.016155029161988452
# Epoch: 12, Batch: 130, Avg. Training Loss: 0.01626854260953574
# Epoch: 12, Batch: 140, Avg. Training Loss: 0.016181615813236162
# Epoch: 12, Batch: 150, Avg. Training Loss: 0.016198356493065762
# Epoch: 12, Batch: 160, Avg. Training Loss: 0.016723120841197685
# Epoch: 12, Batch: 170, Avg. Training Loss: 0.01633352466913709
# Epoch: 12, Batch: 180, Avg. Training Loss: 0.01629558879778619
# Epoch: 12, Batch: 190, Avg. Training Loss: 0.016574639400565326
# Epoch: 12, Batch: 200, Avg. Training Loss: 0.01640430137515069
# Epoch: 12, Batch: 10, Avg. Validation Loss: 0.01195218674838543
#
# Epoch: 12, Avg. Training Loss: 0.01640430137515069 Avg. Validation Loss: 0.012747100170920877
#
# 	Validation loss decreased (0.018790 --> 0.012747).  Saving net ...
#
# Epoch: 13, Batch: 10, Avg. Training Loss: 0.011497438559308648
# Epoch: 13, Batch: 20, Avg. Training Loss: 0.020919028227217494
# Epoch: 13, Batch: 30, Avg. Training Loss: 0.017805461663131916
# Epoch: 13, Batch: 40, Avg. Training Loss: 0.01582015962339938
# Epoch: 13, Batch: 50, Avg. Training Loss: 0.01588661293499172
# Epoch: 13, Batch: 60, Avg. Training Loss: 0.017230119773497192
# Epoch: 13, Batch: 70, Avg. Training Loss: 0.016767632794965598
# Epoch: 13, Batch: 80, Avg. Training Loss: 0.016398356587160386
# Epoch: 13, Batch: 90, Avg. Training Loss: 0.01598645360209048
# Epoch: 13, Batch: 100, Avg. Training Loss: 0.018085130173712972
# Epoch: 13, Batch: 110, Avg. Training Loss: 0.017780344450676982
# Epoch: 13, Batch: 120, Avg. Training Loss: 0.01745621413380528
# Epoch: 13, Batch: 130, Avg. Training Loss: 0.017069104539517023
# Epoch: 13, Batch: 140, Avg. Training Loss: 0.01665705382890467
# Epoch: 13, Batch: 150, Avg. Training Loss: 0.016266202942157783
# Epoch: 13, Batch: 160, Avg. Training Loss: 0.01575842058518901
# Epoch: 13, Batch: 170, Avg. Training Loss: 0.01541895061895689
# Epoch: 13, Batch: 180, Avg. Training Loss: 0.015339441506916445
# Epoch: 13, Batch: 190, Avg. Training Loss: 0.015273796264572358
# Epoch: 13, Batch: 200, Avg. Training Loss: 0.014951156284660096
# Epoch: 13, Batch: 10, Avg. Validation Loss: 0.010076912958174944
#
# Epoch: 13, Avg. Training Loss: 0.014951156284660096 Avg. Validation Loss: 0.01308811321745024
#
# Epoch: 14, Batch: 10, Avg. Training Loss: 0.011519208457320929
# Epoch: 14, Batch: 20, Avg. Training Loss: 0.010724452999420464
# Epoch: 14, Batch: 30, Avg. Training Loss: 0.01885437637877961
# Epoch: 14, Batch: 40, Avg. Training Loss: 0.01765173707390204
# Epoch: 14, Batch: 50, Avg. Training Loss: 0.01585650207474828
# Epoch: 14, Batch: 60, Avg. Training Loss: 0.016509988872955246
# Epoch: 14, Batch: 70, Avg. Training Loss: 0.016224028376330225
# Epoch: 14, Batch: 80, Avg. Training Loss: 0.017085906985448675
# Epoch: 14, Batch: 90, Avg. Training Loss: 0.016655898533968466
# Epoch: 14, Batch: 100, Avg. Training Loss: 0.016024248474277556
# Epoch: 14, Batch: 110, Avg. Training Loss: 0.016472790013490748
# Epoch: 14, Batch: 120, Avg. Training Loss: 0.016111181796683617
# Epoch: 14, Batch: 130, Avg. Training Loss: 0.01586249097823524
# Epoch: 14, Batch: 140, Avg. Training Loss: 0.01576442987258946
# Epoch: 14, Batch: 150, Avg. Training Loss: 0.01575321907488009
# Epoch: 14, Batch: 160, Avg. Training Loss: 0.015785546140978123
# Epoch: 14, Batch: 170, Avg. Training Loss: 0.01543078345301398
# Epoch: 14, Batch: 180, Avg. Training Loss: 0.015220373444673101
# Epoch: 14, Batch: 190, Avg. Training Loss: 0.015791760007605744
# Epoch: 14, Batch: 200, Avg. Training Loss: 0.016245148708112535
# Epoch: 14, Batch: 10, Avg. Validation Loss: 0.01672275415621698
#
# Epoch: 14, Avg. Training Loss: 0.016245148708112535 Avg. Validation Loss: 0.016530622782952645
#
# Epoch: 15, Batch: 10, Avg. Training Loss: 0.022521672863513233
# Epoch: 15, Batch: 20, Avg. Training Loss: 0.015816422551870345
# Epoch: 15, Batch: 30, Avg. Training Loss: 0.014395740255713461
# Epoch: 15, Batch: 40, Avg. Training Loss: 0.013240789319388569
# Epoch: 15, Batch: 50, Avg. Training Loss: 0.013524351110681891
# Epoch: 15, Batch: 60, Avg. Training Loss: 0.013125116347024839
# Epoch: 15, Batch: 70, Avg. Training Loss: 0.01268778330247317
# Epoch: 15, Batch: 80, Avg. Training Loss: 0.012565884192008525
# Epoch: 15, Batch: 90, Avg. Training Loss: 0.013747105587066875
# Epoch: 15, Batch: 100, Avg. Training Loss: 0.013683320824056863
# Epoch: 15, Batch: 110, Avg. Training Loss: 0.01320345955054191
# Epoch: 15, Batch: 120, Avg. Training Loss: 0.012905891973059625
# Epoch: 15, Batch: 130, Avg. Training Loss: 0.013210279347661596
# Epoch: 15, Batch: 140, Avg. Training Loss: 0.013084972806141845
# Epoch: 15, Batch: 150, Avg. Training Loss: 0.0134003821387887
# Epoch: 15, Batch: 160, Avg. Training Loss: 0.013282976031769067
# Epoch: 15, Batch: 170, Avg. Training Loss: 0.013446044694522725
# Epoch: 15, Batch: 180, Avg. Training Loss: 0.014210884073852665
# Epoch: 15, Batch: 190, Avg. Training Loss: 0.01473976275883615
# Epoch: 15, Batch: 200, Avg. Training Loss: 0.014710925330873578
# Epoch: 15, Batch: 10, Avg. Validation Loss: 0.012257365975528955
#
# Epoch: 15, Avg. Training Loss: 0.014710925330873578 Avg. Validation Loss: 0.011841570081956247
#
# 	Validation loss decreased (0.012747 --> 0.011842).  Saving net ...
#
# Epoch: 16, Batch: 10, Avg. Training Loss: 0.0126676834654063
# Epoch: 16, Batch: 20, Avg. Training Loss: 0.014930005837231874
# Epoch: 16, Batch: 30, Avg. Training Loss: 0.016700569105645022
# Epoch: 16, Batch: 40, Avg. Training Loss: 0.01593814780935645
# Epoch: 16, Batch: 50, Avg. Training Loss: 0.015473887212574483
# Epoch: 16, Batch: 60, Avg. Training Loss: 0.01510574067166696
# Epoch: 16, Batch: 70, Avg. Training Loss: 0.014154529917453017
# Epoch: 16, Batch: 80, Avg. Training Loss: 0.013744415598921478
# Epoch: 16, Batch: 90, Avg. Training Loss: 0.013669219385418627
# Epoch: 16, Batch: 100, Avg. Training Loss: 0.013632369791157544
# Epoch: 16, Batch: 110, Avg. Training Loss: 0.013320036431435834
# Epoch: 16, Batch: 120, Avg. Training Loss: 0.013074968669873973
# Epoch: 16, Batch: 130, Avg. Training Loss: 0.012997305740673955
# Epoch: 16, Batch: 140, Avg. Training Loss: 0.012769362845990275
# Epoch: 16, Batch: 150, Avg. Training Loss: 0.012639198200777175
# Epoch: 16, Batch: 160, Avg. Training Loss: 0.012530932904337535
# Epoch: 16, Batch: 170, Avg. Training Loss: 0.012396534113213422
# Epoch: 16, Batch: 180, Avg. Training Loss: 0.01228455705309494
# Epoch: 16, Batch: 190, Avg. Training Loss: 0.012193960468529873
# Epoch: 16, Batch: 200, Avg. Training Loss: 0.012275753014255318
# Epoch: 16, Batch: 10, Avg. Validation Loss: 0.010951213259249925
#
# Epoch: 16, Avg. Training Loss: 0.012275753014255318 Avg. Validation Loss: 0.01422814531799625
#
# Epoch: 17, Batch: 10, Avg. Training Loss: 0.011910774325951935
# Epoch: 17, Batch: 20, Avg. Training Loss: 0.011404364998452366
# Epoch: 17, Batch: 30, Avg. Training Loss: 0.01478237093736728
# Epoch: 17, Batch: 40, Avg. Training Loss: 0.015080497227609157
# Epoch: 17, Batch: 50, Avg. Training Loss: 0.013816718002781272
# Epoch: 17, Batch: 60, Avg. Training Loss: 0.016670559416525066
# Epoch: 17, Batch: 70, Avg. Training Loss: 0.015974171333281058
# Epoch: 17, Batch: 80, Avg. Training Loss: 0.015574283740716056
# Epoch: 17, Batch: 90, Avg. Training Loss: 0.014771361959477265
# Epoch: 17, Batch: 100, Avg. Training Loss: 0.014447827613912523
# Epoch: 17, Batch: 110, Avg. Training Loss: 0.014548603927885944
# Epoch: 17, Batch: 120, Avg. Training Loss: 0.01407713683632513
# Epoch: 17, Batch: 130, Avg. Training Loss: 0.014577660483952898
# Epoch: 17, Batch: 140, Avg. Training Loss: 0.014358432351478509
# Epoch: 17, Batch: 150, Avg. Training Loss: 0.01419690380183359
# Epoch: 17, Batch: 160, Avg. Training Loss: 0.013860688178101554
# Epoch: 17, Batch: 170, Avg. Training Loss: 0.01352982835515457
# Epoch: 17, Batch: 180, Avg. Training Loss: 0.013304489726821581
# Epoch: 17, Batch: 190, Avg. Training Loss: 0.013397148611808294
# Epoch: 17, Batch: 200, Avg. Training Loss: 0.01367941722040996
# Epoch: 17, Batch: 10, Avg. Validation Loss: 0.019343092758208513
#
# Epoch: 17, Avg. Training Loss: 0.01367941722040996 Avg. Validation Loss: 0.016426681869608512
#
# Epoch: 18, Batch: 10, Avg. Training Loss: 0.027990858256816863
# Epoch: 18, Batch: 20, Avg. Training Loss: 0.018572321091778577
# Epoch: 18, Batch: 30, Avg. Training Loss: 0.016351615435754252
# Epoch: 18, Batch: 40, Avg. Training Loss: 0.01636849840870127
# Epoch: 18, Batch: 50, Avg. Training Loss: 0.015000234032049777
# Epoch: 18, Batch: 60, Avg. Training Loss: 0.013971268905637166
# Epoch: 18, Batch: 70, Avg. Training Loss: 0.014826899460916008
# Epoch: 18, Batch: 80, Avg. Training Loss: 0.014347807853482664
# Epoch: 18, Batch: 90, Avg. Training Loss: 0.013880565452078978
# Epoch: 18, Batch: 100, Avg. Training Loss: 0.013976428098976612
# Epoch: 18, Batch: 110, Avg. Training Loss: 0.013692109794779257
# Epoch: 18, Batch: 120, Avg. Training Loss: 0.013443424467307825
# Epoch: 18, Batch: 130, Avg. Training Loss: 0.013458943116263701
# Epoch: 18, Batch: 140, Avg. Training Loss: 0.013262164386521494
# Epoch: 18, Batch: 150, Avg. Training Loss: 0.013047433895990253
# Epoch: 18, Batch: 160, Avg. Training Loss: 0.012729235098231585
# Epoch: 18, Batch: 170, Avg. Training Loss: 0.012478574792690137
# Epoch: 18, Batch: 180, Avg. Training Loss: 0.012187798279854986
# Epoch: 18, Batch: 190, Avg. Training Loss: 0.012014850611357313
# Epoch: 18, Batch: 200, Avg. Training Loss: 0.012205705889500677
# Epoch: 18, Batch: 10, Avg. Validation Loss: 0.018257614690810442
#
# Epoch: 18, Avg. Training Loss: 0.012205705889500677 Avg. Validation Loss: 0.0156420047449715
#
# Epoch: 19, Batch: 10, Avg. Training Loss: 0.007913264026865364
# Epoch: 19, Batch: 20, Avg. Training Loss: 0.007588387373834849
# Epoch: 19, Batch: 30, Avg. Training Loss: 0.011537092737853527
# Epoch: 19, Batch: 40, Avg. Training Loss: 0.02248948614578694
# Epoch: 19, Batch: 50, Avg. Training Loss: 0.020810360051691533
# Epoch: 19, Batch: 60, Avg. Training Loss: 0.024176209047436715
# Epoch: 19, Batch: 70, Avg. Training Loss: 0.023502256415252176
# Epoch: 19, Batch: 80, Avg. Training Loss: 0.022538710100343456
# Epoch: 19, Batch: 90, Avg. Training Loss: 0.021734988228935343
# Epoch: 19, Batch: 100, Avg. Training Loss: 0.020906890225596733
# Epoch: 19, Batch: 110, Avg. Training Loss: 0.019899379622868526
# Epoch: 19, Batch: 120, Avg. Training Loss: 0.019131871541806813
# Epoch: 19, Batch: 130, Avg. Training Loss: 0.01856777311231082
# Epoch: 19, Batch: 140, Avg. Training Loss: 0.01786818888171444
# Epoch: 19, Batch: 150, Avg. Training Loss: 0.017366028660908354
# Epoch: 19, Batch: 160, Avg. Training Loss: 0.017052504883031373
# Epoch: 19, Batch: 170, Avg. Training Loss: 0.016974545686560528
# Epoch: 19, Batch: 180, Avg. Training Loss: 0.01686489865339052
# Epoch: 19, Batch: 190, Avg. Training Loss: 0.0164779759673892
# Epoch: 19, Batch: 200, Avg. Training Loss: 0.016378223339561383
# Epoch: 19, Batch: 10, Avg. Validation Loss: 0.013850615825504065
#
# Epoch: 19, Avg. Training Loss: 0.016378223339561383 Avg. Validation Loss: 0.013372699620530885
#
# Epoch: 20, Batch: 10, Avg. Training Loss: 0.011107592843472958
# Epoch: 20, Batch: 20, Avg. Training Loss: 0.010596983041614294
# Epoch: 20, Batch: 30, Avg. Training Loss: 0.010343362670391798
# Epoch: 20, Batch: 40, Avg. Training Loss: 0.018737779115326703
# Epoch: 20, Batch: 50, Avg. Training Loss: 0.01800179876387119
# Epoch: 20, Batch: 60, Avg. Training Loss: 0.016949283704161645
# Epoch: 20, Batch: 70, Avg. Training Loss: 0.01690573529340327
# Epoch: 20, Batch: 80, Avg. Training Loss: 0.016002859949367124
# Epoch: 20, Batch: 90, Avg. Training Loss: 0.01631402505251269
# Epoch: 20, Batch: 100, Avg. Training Loss: 0.016029501236043874
# Epoch: 20, Batch: 110, Avg. Training Loss: 0.016396808243271978
# Epoch: 20, Batch: 120, Avg. Training Loss: 0.01629239999456331
# Epoch: 20, Batch: 130, Avg. Training Loss: 0.01595396353290058
# Epoch: 20, Batch: 140, Avg. Training Loss: 0.016078528452531566
# Epoch: 20, Batch: 150, Avg. Training Loss: 0.015982902441173796
# Epoch: 20, Batch: 160, Avg. Training Loss: 0.015720689052250235
# Epoch: 20, Batch: 170, Avg. Training Loss: 0.015369498335263305
# Epoch: 20, Batch: 180, Avg. Training Loss: 0.015051181968818933
# Epoch: 20, Batch: 190, Avg. Training Loss: 0.015244849207565971
# Epoch: 20, Batch: 200, Avg. Training Loss: 0.015614530718885357
# Epoch: 20, Batch: 10, Avg. Validation Loss: 0.008696112735196947
#
# Epoch: 20, Avg. Training Loss: 0.015614530718885357 Avg. Validation Loss: 0.011425733210190255
#
# 	Validation loss decreased (0.011842 --> 0.011426).  Saving net ...
#
# Epoch: 21, Batch: 10, Avg. Training Loss: 0.02602169020101428
# Epoch: 21, Batch: 20, Avg. Training Loss: 0.02138085481710732
# Epoch: 21, Batch: 30, Avg. Training Loss: 0.019852339755743742
# Epoch: 21, Batch: 40, Avg. Training Loss: 0.01843355770688504
# Epoch: 21, Batch: 50, Avg. Training Loss: 0.016498641483485697
# Epoch: 21, Batch: 60, Avg. Training Loss: 0.017327276042973003
# Epoch: 21, Batch: 70, Avg. Training Loss: 0.016370322295863715
# Epoch: 21, Batch: 80, Avg. Training Loss: 0.01617377599468455
# Epoch: 21, Batch: 90, Avg. Training Loss: 0.016309380572703154
# Epoch: 21, Batch: 100, Avg. Training Loss: 0.01595675590448082
# Epoch: 21, Batch: 110, Avg. Training Loss: 0.015410093006423934
# Epoch: 21, Batch: 120, Avg. Training Loss: 0.015135511965490882
# Epoch: 21, Batch: 130, Avg. Training Loss: 0.01474939299962269
# Epoch: 21, Batch: 140, Avg. Training Loss: 0.014906295565223061
# Epoch: 21, Batch: 150, Avg. Training Loss: 0.014640930332243448
# Epoch: 21, Batch: 160, Avg. Training Loss: 0.01426340585458093
# Epoch: 21, Batch: 170, Avg. Training Loss: 0.014021047196515347
# Epoch: 21, Batch: 180, Avg. Training Loss: 0.01379980621600731
# Epoch: 21, Batch: 190, Avg. Training Loss: 0.013761129622396675
# Epoch: 21, Batch: 200, Avg. Training Loss: 0.013445479653310034
# Epoch: 21, Batch: 10, Avg. Validation Loss: 0.00935168219730258
#
# Epoch: 21, Avg. Training Loss: 0.013445479653310034 Avg. Validation Loss: 0.009964035330888103
#
# 	Validation loss decreased (0.011426 --> 0.009964).  Saving net ...
#
# Epoch: 22, Batch: 10, Avg. Training Loss: 0.012057761056348681
# Epoch: 22, Batch: 20, Avg. Training Loss: 0.010403179819695652
# Epoch: 22, Batch: 30, Avg. Training Loss: 0.011432038915033142
# Epoch: 22, Batch: 40, Avg. Training Loss: 0.010869797330815344
# Epoch: 22, Batch: 50, Avg. Training Loss: 0.010869647385552525
# Epoch: 22, Batch: 60, Avg. Training Loss: 0.011208584563185771
# Epoch: 22, Batch: 70, Avg. Training Loss: 0.010678026845146503
# Epoch: 22, Batch: 80, Avg. Training Loss: 0.01015085612889379
# Epoch: 22, Batch: 90, Avg. Training Loss: 0.00997439353312883
# Epoch: 22, Batch: 100, Avg. Training Loss: 0.009901992850936951
# Epoch: 22, Batch: 110, Avg. Training Loss: 0.009672880824655297
# Epoch: 22, Batch: 120, Avg. Training Loss: 0.00961016006379699
# Epoch: 22, Batch: 130, Avg. Training Loss: 0.009983216566391864
# Epoch: 22, Batch: 140, Avg. Training Loss: 0.010145327734893989
# Epoch: 22, Batch: 150, Avg. Training Loss: 0.01073269618985554
# Epoch: 22, Batch: 160, Avg. Training Loss: 0.010633947511087174
# Epoch: 22, Batch: 170, Avg. Training Loss: 0.01068326903178412
# Epoch: 22, Batch: 180, Avg. Training Loss: 0.010681665008370252
# Epoch: 22, Batch: 190, Avg. Training Loss: 0.010496274734798236
# Epoch: 22, Batch: 200, Avg. Training Loss: 0.010438565346412364
# Epoch: 22, Batch: 10, Avg. Validation Loss: 0.009981212764978408
#
# Epoch: 22, Avg. Training Loss: 0.010438565346412364 Avg. Validation Loss: 0.010255871011930354
#
# Epoch: 23, Batch: 10, Avg. Training Loss: 0.010369231691583991
# Epoch: 23, Batch: 20, Avg. Training Loss: 0.015438956255093218
# Epoch: 23, Batch: 30, Avg. Training Loss: 0.014292441292976339
# Epoch: 23, Batch: 40, Avg. Training Loss: 0.013065140170510858
# Epoch: 23, Batch: 50, Avg. Training Loss: 0.011994119537994265
# Epoch: 23, Batch: 60, Avg. Training Loss: 0.011575189605355262
# Epoch: 23, Batch: 70, Avg. Training Loss: 0.014164423503513848
# Epoch: 23, Batch: 80, Avg. Training Loss: 0.01391291882027872
# Epoch: 23, Batch: 90, Avg. Training Loss: 0.0132758480289744
# Epoch: 23, Batch: 100, Avg. Training Loss: 0.012790721603669225
# Epoch: 23, Batch: 110, Avg. Training Loss: 0.01237432794560763
# Epoch: 23, Batch: 120, Avg. Training Loss: 0.011982393319097657
# Epoch: 23, Batch: 130, Avg. Training Loss: 0.011935315431597142
# Epoch: 23, Batch: 140, Avg. Training Loss: 0.011937132042034395
# Epoch: 23, Batch: 150, Avg. Training Loss: 0.01692439556432267
# Epoch: 23, Batch: 160, Avg. Training Loss: 0.03886196227103937
# Epoch: 23, Batch: 170, Avg. Training Loss: 0.04019131337511627
# Epoch: 23, Batch: 180, Avg. Training Loss: 0.03950885033700613
# Epoch: 23, Batch: 190, Avg. Training Loss: 0.038629587546088966
# Epoch: 23, Batch: 200, Avg. Training Loss: 0.03764521003467962
# Epoch: 23, Batch: 10, Avg. Validation Loss: 0.02566748345270753
#
# Epoch: 23, Avg. Training Loss: 0.03764521003467962 Avg. Validation Loss: 0.023561101242461625
#
# Epoch: 24, Batch: 10, Avg. Training Loss: 0.017310239374637604
# Epoch: 24, Batch: 20, Avg. Training Loss: 0.020292527228593826
# Epoch: 24, Batch: 30, Avg. Training Loss: 0.018468704540282488
# Epoch: 24, Batch: 40, Avg. Training Loss: 0.01679160053608939
# Epoch: 24, Batch: 50, Avg. Training Loss: 0.015654206108301875
# Epoch: 24, Batch: 60, Avg. Training Loss: 0.01692141994523505
# Epoch: 24, Batch: 70, Avg. Training Loss: 0.016858446551486845
# Epoch: 24, Batch: 80, Avg. Training Loss: 0.016272796440171072
# Epoch: 24, Batch: 90, Avg. Training Loss: 0.015449118515890498
# Epoch: 24, Batch: 100, Avg. Training Loss: 0.015100480602122837
# Epoch: 24, Batch: 110, Avg. Training Loss: 0.01491688871332867
# Epoch: 24, Batch: 120, Avg. Training Loss: 0.014416185118413215
# Epoch: 24, Batch: 130, Avg. Training Loss: 0.014287834994208349
# Epoch: 24, Batch: 140, Avg. Training Loss: 0.01395584403071552
# Epoch: 24, Batch: 150, Avg. Training Loss: 0.013937788785745694
# Epoch: 24, Batch: 160, Avg. Training Loss: 0.014255047691403882
# Epoch: 24, Batch: 170, Avg. Training Loss: 0.013868516913669946
# Epoch: 24, Batch: 180, Avg. Training Loss: 0.013567814660362066
# Epoch: 24, Batch: 190, Avg. Training Loss: 0.013368772038895829
# Epoch: 24, Batch: 200, Avg. Training Loss: 0.01306033797562122
# Epoch: 24, Batch: 10, Avg. Validation Loss: 0.015294067095965147
#
# Epoch: 24, Avg. Training Loss: 0.01306033797562122 Avg. Validation Loss: 0.013161544825005181
#
# Epoch: 25, Batch: 10, Avg. Training Loss: 0.00895903343334794
# Epoch: 25, Batch: 20, Avg. Training Loss: 0.011773206968791783
# Epoch: 25, Batch: 30, Avg. Training Loss: 0.011217587208375335
# Epoch: 25, Batch: 40, Avg. Training Loss: 0.012240352341905238
# Epoch: 25, Batch: 50, Avg. Training Loss: 0.011243536164984106
# Epoch: 25, Batch: 60, Avg. Training Loss: 0.011473946738988161
# Epoch: 25, Batch: 70, Avg. Training Loss: 0.011144261767289469
# Epoch: 25, Batch: 80, Avg. Training Loss: 0.010983185807708651
# Epoch: 25, Batch: 90, Avg. Training Loss: 0.010685414774343373
# Epoch: 25, Batch: 100, Avg. Training Loss: 0.01125258304178715
# Epoch: 25, Batch: 110, Avg. Training Loss: 0.010916675449433654
# Epoch: 25, Batch: 120, Avg. Training Loss: 0.010566193505655975
# Epoch: 25, Batch: 130, Avg. Training Loss: 0.011781226098537446
# Epoch: 25, Batch: 140, Avg. Training Loss: 0.011576648538799158
# Epoch: 25, Batch: 150, Avg. Training Loss: 0.011803027928496398
# Epoch: 25, Batch: 160, Avg. Training Loss: 0.01162329268117901
# Epoch: 25, Batch: 170, Avg. Training Loss: 0.011947831779937534
# Epoch: 25, Batch: 180, Avg. Training Loss: 0.011959769351718327
# Epoch: 25, Batch: 190, Avg. Training Loss: 0.011859509890506926
# Epoch: 25, Batch: 200, Avg. Training Loss: 0.012034530648961664
# Epoch: 25, Batch: 10, Avg. Validation Loss: 0.013073324970901013
#
# Epoch: 25, Avg. Training Loss: 0.012034530648961664 Avg. Validation Loss: 0.0128221555667765
#
# Epoch: 26, Batch: 10, Avg. Training Loss: 0.00870489957742393
# Epoch: 26, Batch: 20, Avg. Training Loss: 0.009643541951663795
# Epoch: 26, Batch: 30, Avg. Training Loss: 0.011879391766463717
# Epoch: 26, Batch: 40, Avg. Training Loss: 0.012407559284474701
# Epoch: 26, Batch: 50, Avg. Training Loss: 0.011931718541309238
# Epoch: 26, Batch: 60, Avg. Training Loss: 0.011506939632818102
# Epoch: 26, Batch: 70, Avg. Training Loss: 0.01121545241081289
# Epoch: 26, Batch: 80, Avg. Training Loss: 0.01098398116300814
# Epoch: 26, Batch: 90, Avg. Training Loss: 0.011136156077393232
# Epoch: 26, Batch: 100, Avg. Training Loss: 0.012661077161319558
# Epoch: 26, Batch: 110, Avg. Training Loss: 0.012283023933626038
# Epoch: 26, Batch: 120, Avg. Training Loss: 0.011851164861582223
# Epoch: 26, Batch: 130, Avg. Training Loss: 0.011529793450608852
# Epoch: 26, Batch: 140, Avg. Training Loss: 0.011232487907234051
# Epoch: 26, Batch: 150, Avg. Training Loss: 0.011039405409246687
# Epoch: 26, Batch: 160, Avg. Training Loss: 0.011144110481836837
# Epoch: 26, Batch: 170, Avg. Training Loss: 0.011757332064649639
# Epoch: 26, Batch: 180, Avg. Training Loss: 0.011589859312193262
# Epoch: 26, Batch: 190, Avg. Training Loss: 0.011407458943952072
# Epoch: 26, Batch: 200, Avg. Training Loss: 0.011278272431809455
# Epoch: 26, Batch: 10, Avg. Validation Loss: 0.00901979384943843
#
# Epoch: 26, Avg. Training Loss: 0.011278272431809455 Avg. Validation Loss: 0.013154095860526842
#
# Epoch: 27, Batch: 10, Avg. Training Loss: 0.015225466107949615
# Epoch: 27, Batch: 20, Avg. Training Loss: 0.010763793403748423
# Epoch: 27, Batch: 30, Avg. Training Loss: 0.010126782744191588
# Epoch: 27, Batch: 40, Avg. Training Loss: 0.010594509163638577
# Epoch: 27, Batch: 50, Avg. Training Loss: 0.011104897134937347
# Epoch: 27, Batch: 60, Avg. Training Loss: 0.01064339434960857
# Epoch: 27, Batch: 70, Avg. Training Loss: 0.01036368677326079
# Epoch: 27, Batch: 80, Avg. Training Loss: 0.010464023161330258
# Epoch: 27, Batch: 90, Avg. Training Loss: 0.011581038210230567
# Epoch: 27, Batch: 100, Avg. Training Loss: 0.011450305862817912
# Epoch: 27, Batch: 110, Avg. Training Loss: 0.011183157489127054
# Epoch: 27, Batch: 120, Avg. Training Loss: 0.011567804584046824
# Epoch: 27, Batch: 130, Avg. Training Loss: 0.011302208658665991
# Epoch: 27, Batch: 140, Avg. Training Loss: 0.011340295318846724
# Epoch: 27, Batch: 150, Avg. Training Loss: 0.011053338179675241
# Epoch: 27, Batch: 160, Avg. Training Loss: 0.011126381957728883
# Epoch: 27, Batch: 170, Avg. Training Loss: 0.010895523205673432
# Epoch: 27, Batch: 180, Avg. Training Loss: 0.011404070106800645
# Epoch: 27, Batch: 190, Avg. Training Loss: 0.01130250417014682
# Epoch: 27, Batch: 200, Avg. Training Loss: 0.011616044469410553
# Epoch: 27, Batch: 10, Avg. Validation Loss: 0.008943639975041152
#
# Epoch: 27, Avg. Training Loss: 0.011616044469410553 Avg. Validation Loss: 0.008849761503584245
#
# 	Validation loss decreased (0.009964 --> 0.008850).  Saving net ...
#
# Epoch: 28, Batch: 10, Avg. Training Loss: 0.014626414747908711
# Epoch: 28, Batch: 20, Avg. Training Loss: 0.014372126618400215
# Epoch: 28, Batch: 30, Avg. Training Loss: 0.013076715885351102
# Epoch: 28, Batch: 40, Avg. Training Loss: 0.012013880710583178
# Epoch: 28, Batch: 50, Avg. Training Loss: 0.01137986931949854
# Epoch: 28, Batch: 60, Avg. Training Loss: 0.016551372517521184
# Epoch: 28, Batch: 70, Avg. Training Loss: 0.01662119021639228
# Epoch: 28, Batch: 80, Avg. Training Loss: 0.016676883108448233
# Epoch: 28, Batch: 90, Avg. Training Loss: 0.015883885556831956
# Epoch: 28, Batch: 100, Avg. Training Loss: 0.015226011448539793
# Epoch: 28, Batch: 110, Avg. Training Loss: 0.01449947435070168
# Epoch: 28, Batch: 120, Avg. Training Loss: 0.014399292094943424
# Epoch: 28, Batch: 130, Avg. Training Loss: 0.013967372509292685
# Epoch: 28, Batch: 140, Avg. Training Loss: 0.013620102618421828
# Epoch: 28, Batch: 150, Avg. Training Loss: 0.013664068626239896
# Epoch: 28, Batch: 160, Avg. Training Loss: 0.013334374508121982
# Epoch: 28, Batch: 170, Avg. Training Loss: 0.013035375008578686
# Epoch: 28, Batch: 180, Avg. Training Loss: 0.012926681246608496
# Epoch: 28, Batch: 190, Avg. Training Loss: 0.01301931718266324
# Epoch: 28, Batch: 200, Avg. Training Loss: 0.012909780731424689
# Epoch: 28, Batch: 10, Avg. Validation Loss: 0.011171867232769727
#
# Epoch: 28, Avg. Training Loss: 0.012909780731424689 Avg. Validation Loss: 0.010992831769673264
#
# Epoch: 29, Batch: 10, Avg. Training Loss: 0.025111166248098015
# Epoch: 29, Batch: 20, Avg. Training Loss: 0.01766560538671911
# Epoch: 29, Batch: 30, Avg. Training Loss: 0.01479337390822669
# Epoch: 29, Batch: 40, Avg. Training Loss: 0.013317438098601997
# Epoch: 29, Batch: 50, Avg. Training Loss: 0.012109499918296933
# Epoch: 29, Batch: 60, Avg. Training Loss: 0.011360925676611563
# Epoch: 29, Batch: 70, Avg. Training Loss: 0.011191361743424619
# Epoch: 29, Batch: 80, Avg. Training Loss: 0.010623490851139651
# Epoch: 29, Batch: 90, Avg. Training Loss: 0.01023372451050414
# Epoch: 29, Batch: 100, Avg. Training Loss: 0.009870142280124127
# Epoch: 29, Batch: 110, Avg. Training Loss: 0.009660747219723735
# Epoch: 29, Batch: 120, Avg. Training Loss: 0.009497471087767433
# Epoch: 29, Batch: 130, Avg. Training Loss: 0.009464111010758922
# Epoch: 29, Batch: 140, Avg. Training Loss: 0.00926619892540787
# Epoch: 29, Batch: 150, Avg. Training Loss: 0.00912872100869815
# Epoch: 29, Batch: 160, Avg. Training Loss: 0.009015277138678359
# Epoch: 29, Batch: 170, Avg. Training Loss: 0.008855078845997072
# Epoch: 29, Batch: 180, Avg. Training Loss: 0.008751982529388955
# Epoch: 29, Batch: 190, Avg. Training Loss: 0.008628006370149951
# Epoch: 29, Batch: 200, Avg. Training Loss: 0.008628325669560587
# Epoch: 29, Batch: 10, Avg. Validation Loss: 0.007505917083472013
#
# Epoch: 29, Avg. Training Loss: 0.008628325669560587 Avg. Validation Loss: 0.008743912145933685
#
# 	Validation loss decreased (0.008850 --> 0.008744).  Saving net ...
#
# Epoch: 30, Batch: 10, Avg. Training Loss: 0.006987076578661799
# Epoch: 30, Batch: 20, Avg. Training Loss: 0.006928368355147541
# Epoch: 30, Batch: 30, Avg. Training Loss: 0.007737478598331413
# Epoch: 30, Batch: 40, Avg. Training Loss: 0.0078124635736458005
# Epoch: 30, Batch: 50, Avg. Training Loss: 0.007601357540115714
# Epoch: 30, Batch: 60, Avg. Training Loss: 0.008377770567312837
# Epoch: 30, Batch: 70, Avg. Training Loss: 0.008223064775977814
# Epoch: 30, Batch: 80, Avg. Training Loss: 0.008068695649853904
# Epoch: 30, Batch: 90, Avg. Training Loss: 0.008300603082817461
# Epoch: 30, Batch: 100, Avg. Training Loss: 0.008137223508674648
# Epoch: 30, Batch: 110, Avg. Training Loss: 0.00811996597754345
# Epoch: 30, Batch: 120, Avg. Training Loss: 0.008080704256038485
# Epoch: 30, Batch: 130, Avg. Training Loss: 0.007945540767664513
# Epoch: 30, Batch: 140, Avg. Training Loss: 0.008230100497270793
# Epoch: 30, Batch: 150, Avg. Training Loss: 0.008161838742283474
# Epoch: 30, Batch: 160, Avg. Training Loss: 0.008336002989381076
# Epoch: 30, Batch: 170, Avg. Training Loss: 0.008398146753418519
# Epoch: 30, Batch: 180, Avg. Training Loss: 0.008337394397757523
# Epoch: 30, Batch: 190, Avg. Training Loss: 0.008271248277129693
# Epoch: 30, Batch: 200, Avg. Training Loss: 0.008217194819590063
# Epoch: 30, Batch: 10, Avg. Validation Loss: 0.007103488640859723
#
# Epoch: 30, Avg. Training Loss: 0.008217194819590063 Avg. Validation Loss: 0.007213258622762035
#
# 	Validation loss decreased (0.008744 --> 0.007213).  Saving net ...
#
# Epoch: 31, Batch: 10, Avg. Training Loss: 0.005638192547485233
# Epoch: 31, Batch: 20, Avg. Training Loss: 0.009737319778650999
# Epoch: 31, Batch: 30, Avg. Training Loss: 0.01105210881990691
# Epoch: 31, Batch: 40, Avg. Training Loss: 0.010803177830530331
# Epoch: 31, Batch: 50, Avg. Training Loss: 0.0100692885229364
# Epoch: 31, Batch: 60, Avg. Training Loss: 0.0096641343125763
# Epoch: 31, Batch: 70, Avg. Training Loss: 0.00943585625916187
# Epoch: 31, Batch: 80, Avg. Training Loss: 0.00941689110768493
# Epoch: 31, Batch: 90, Avg. Training Loss: 0.009251235562583638
# Epoch: 31, Batch: 100, Avg. Training Loss: 0.009165804404765363
# Epoch: 31, Batch: 110, Avg. Training Loss: 0.009218032027340749
# Epoch: 31, Batch: 120, Avg. Training Loss: 0.009011281130369753
# Epoch: 31, Batch: 130, Avg. Training Loss: 0.00877481225448159
# Epoch: 31, Batch: 140, Avg. Training Loss: 0.008550282178579699
# Epoch: 31, Batch: 150, Avg. Training Loss: 0.008535955619687835
# Epoch: 31, Batch: 160, Avg. Training Loss: 0.008495322027010843
# Epoch: 31, Batch: 170, Avg. Training Loss: 0.008445466701489159
# Epoch: 31, Batch: 180, Avg. Training Loss: 0.008344852982554583
# Epoch: 31, Batch: 190, Avg. Training Loss: 0.008268276439048348
# Epoch: 31, Batch: 200, Avg. Training Loss: 0.008213902533752841
# Epoch: 31, Batch: 10, Avg. Validation Loss: 0.008588320389389992
#
# Epoch: 31, Avg. Training Loss: 0.008213902533752841 Avg. Validation Loss: 0.009093352155212094
#
# Epoch: 32, Batch: 10, Avg. Training Loss: 0.006913858000189066
# Epoch: 32, Batch: 20, Avg. Training Loss: 0.006325443205423653
# Epoch: 32, Batch: 30, Avg. Training Loss: 0.007438650246088704
# Epoch: 32, Batch: 40, Avg. Training Loss: 0.007661290798569098
# Epoch: 32, Batch: 50, Avg. Training Loss: 0.00807906917762011
# Epoch: 32, Batch: 60, Avg. Training Loss: 0.008830874618918943
# Epoch: 32, Batch: 70, Avg. Training Loss: 0.009377447352744636
# Epoch: 32, Batch: 80, Avg. Training Loss: 0.00934471990622114
# Epoch: 32, Batch: 90, Avg. Training Loss: 0.009138023498882016
# Epoch: 32, Batch: 100, Avg. Training Loss: 0.008881797243375324
# Epoch: 32, Batch: 110, Avg. Training Loss: 0.00886764343277635
# Epoch: 32, Batch: 120, Avg. Training Loss: 0.008767165493918575
# Epoch: 32, Batch: 130, Avg. Training Loss: 0.008694457063952884
# Epoch: 32, Batch: 140, Avg. Training Loss: 0.008930120272894517
# Epoch: 32, Batch: 150, Avg. Training Loss: 0.009074854448748127
# Epoch: 32, Batch: 160, Avg. Training Loss: 0.008898386939836196
# Epoch: 32, Batch: 170, Avg. Training Loss: 0.008863832107197272
# Epoch: 32, Batch: 180, Avg. Training Loss: 0.008767348469700662
# Epoch: 32, Batch: 190, Avg. Training Loss: 0.008649099651282945
# Epoch: 32, Batch: 200, Avg. Training Loss: 0.008575352064799516
# Epoch: 32, Batch: 10, Avg. Validation Loss: 0.00812495150603354
#
# Epoch: 32, Avg. Training Loss: 0.008575352064799516 Avg. Validation Loss: 0.008768444497357397
#
# Epoch: 33, Batch: 10, Avg. Training Loss: 0.008948583900928498
# Epoch: 33, Batch: 20, Avg. Training Loss: 0.007980483444407582
# Epoch: 33, Batch: 30, Avg. Training Loss: 0.007562426726023355
# Epoch: 33, Batch: 40, Avg. Training Loss: 0.007316851854557172
# Epoch: 33, Batch: 50, Avg. Training Loss: 0.008412230503745377
# Epoch: 33, Batch: 60, Avg. Training Loss: 0.009429723703457663
# Epoch: 33, Batch: 70, Avg. Training Loss: 0.009432159048239035
# Epoch: 33, Batch: 80, Avg. Training Loss: 0.009946328873047606
# Epoch: 33, Batch: 90, Avg. Training Loss: 0.009864366106275056
# Epoch: 33, Batch: 100, Avg. Training Loss: 0.009817929840646689
# Epoch: 33, Batch: 110, Avg. Training Loss: 0.00955469739962031
# Epoch: 33, Batch: 120, Avg. Training Loss: 0.009295874434368068
# Epoch: 33, Batch: 130, Avg. Training Loss: 0.00912114966911479
# Epoch: 33, Batch: 140, Avg. Training Loss: 0.008945267988435394
# Epoch: 33, Batch: 150, Avg. Training Loss: 0.009524390661778551
# Epoch: 33, Batch: 160, Avg. Training Loss: 0.009578669148322661
# Epoch: 33, Batch: 170, Avg. Training Loss: 0.009464683123480746
# Epoch: 33, Batch: 180, Avg. Training Loss: 0.009495337015121346
# Epoch: 33, Batch: 190, Avg. Training Loss: 0.009421966960163494
# Epoch: 33, Batch: 200, Avg. Training Loss: 0.009588028751313687
# Epoch: 33, Batch: 10, Avg. Validation Loss: 0.01557006505317986
#
# Epoch: 33, Avg. Training Loss: 0.009588028751313687 Avg. Validation Loss: 0.013974046142881408
#
# Epoch: 34, Batch: 10, Avg. Training Loss: 0.007955202227458357
# Epoch: 34, Batch: 20, Avg. Training Loss: 0.008345917938277126
# Epoch: 34, Batch: 30, Avg. Training Loss: 0.007750558822105328
# Epoch: 34, Batch: 40, Avg. Training Loss: 0.007545348908752203
# ...
# Epoch: 90, Batch: 20, Avg. Training Loss: 0.0032487775781191884
# Epoch: 90, Batch: 30, Avg. Training Loss: 0.003343533095903695
# Epoch: 90, Batch: 40, Avg. Training Loss: 0.0033707859634887426
# Epoch: 90, Batch: 50, Avg. Training Loss: 0.003457188275642693
# Epoch: 90, Batch: 60, Avg. Training Loss: 0.0034451963923250637
# Epoch: 90, Batch: 70, Avg. Training Loss: 0.0038003443773569805
# Epoch: 90, Batch: 80, Avg. Training Loss: 0.003974342058063485
# Epoch: 90, Batch: 90, Avg. Training Loss: 0.004193634322534005
# Epoch: 90, Batch: 100, Avg. Training Loss: 0.004255317316856235
# Epoch: 90, Batch: 110, Avg. Training Loss: 0.004265297564085235
# Epoch: 90, Batch: 120, Avg. Training Loss: 0.0042867939356559265
# Epoch: 90, Batch: 130, Avg. Training Loss: 0.004336891522129568
# Epoch: 90, Batch: 140, Avg. Training Loss: 0.004330173628737352
# Epoch: 90, Batch: 150, Avg. Training Loss: 0.004405334854188064
# Epoch: 90, Batch: 160, Avg. Training Loss: 0.004415305198926946
# Epoch: 90, Batch: 170, Avg. Training Loss: 0.004476583334069481
# Epoch: 90, Batch: 180, Avg. Training Loss: 0.0044550978643302305
# Epoch: 90, Batch: 190, Avg. Training Loss: 0.004543618143438117
# Epoch: 90, Batch: 200, Avg. Training Loss: 0.004597504491684958
# Epoch: 90, Batch: 10, Avg. Validation Loss: 0.00599964577704668
#
# Epoch: 90, Avg. Training Loss: 0.004597504491684958 Avg. Validation Loss: 0.007605826235650217
#
# Epoch: 91, Batch: 10, Avg. Training Loss: 0.00381533217150718
# Epoch: 91, Batch: 20, Avg. Training Loss: 0.0043766994029283525
# Epoch: 91, Batch: 30, Avg. Training Loss: 0.004681187604243557
# Epoch: 91, Batch: 40, Avg. Training Loss: 0.005400974227814004
# Epoch: 91, Batch: 50, Avg. Training Loss: 0.0054474038863554595
# Epoch: 91, Batch: 60, Avg. Training Loss: 0.0052543291666855415
# Epoch: 91, Batch: 70, Avg. Training Loss: 0.005022269597143999
# Epoch: 91, Batch: 80, Avg. Training Loss: 0.0048790954257128755
# Epoch: 91, Batch: 90, Avg. Training Loss: 0.00483971570049309
# Epoch: 91, Batch: 100, Avg. Training Loss: 0.004726485260762273
# Epoch: 91, Batch: 110, Avg. Training Loss: 0.004622337512079287
# Epoch: 91, Batch: 120, Avg. Training Loss: 0.004588665314561997
# Epoch: 91, Batch: 130, Avg. Training Loss: 0.004605252537518166
# Epoch: 91, Batch: 140, Avg. Training Loss: 0.004583485128491052
# Epoch: 91, Batch: 150, Avg. Training Loss: 0.00473818144450585
# Epoch: 91, Batch: 160, Avg. Training Loss: 0.00470994234783575
# Epoch: 91, Batch: 170, Avg. Training Loss: 0.0046906163299675376
# Epoch: 91, Batch: 180, Avg. Training Loss: 0.0046933016403474725
# Epoch: 91, Batch: 190, Avg. Training Loss: 0.004669808085370609
# Epoch: 91, Batch: 200, Avg. Training Loss: 0.004638036100659517
# Epoch: 91, Batch: 10, Avg. Validation Loss: 0.004887937474995852
#
# Epoch: 91, Avg. Training Loss: 0.004638036100659517 Avg. Validation Loss: 0.0058177279390613824
#
# 	Validation loss decreased (0.006272 --> 0.005818).  Saving net ...
#
# Epoch: 92, Batch: 10, Avg. Training Loss: 0.004821442905813456
# Epoch: 92, Batch: 20, Avg. Training Loss: 0.010459031630307435
# Epoch: 92, Batch: 30, Avg. Training Loss: 0.009022673692864676
# Epoch: 92, Batch: 40, Avg. Training Loss: 0.00812093486310914
# Epoch: 92, Batch: 50, Avg. Training Loss: 0.008529719929210838
# Epoch: 92, Batch: 60, Avg. Training Loss: 0.007917086124264944
# Epoch: 92, Batch: 70, Avg. Training Loss: 0.00739610697408872
# Epoch: 92, Batch: 80, Avg. Training Loss: 0.006964807398617268
# Epoch: 92, Batch: 90, Avg. Training Loss: 0.006919403700158
# Epoch: 92, Batch: 100, Avg. Training Loss: 0.006690590747166425
# Epoch: 92, Batch: 110, Avg. Training Loss: 0.006514636662111364
# Epoch: 92, Batch: 120, Avg. Training Loss: 0.006379221653332934
# Epoch: 92, Batch: 130, Avg. Training Loss: 0.007706567978199858
# Epoch: 92, Batch: 140, Avg. Training Loss: 0.007687821994269533
# Epoch: 92, Batch: 150, Avg. Training Loss: 0.007518373838004967
# Epoch: 92, Batch: 160, Avg. Training Loss: 0.0073944288480561225
# Epoch: 92, Batch: 170, Avg. Training Loss: 0.00726593455491478
# Epoch: 92, Batch: 180, Avg. Training Loss: 0.007150355113359789
# Epoch: 92, Batch: 190, Avg. Training Loss: 0.006970085317612087
# Epoch: 92, Batch: 200, Avg. Training Loss: 0.006858746120706201
# Epoch: 92, Batch: 10, Avg. Validation Loss: 0.008818268845789134
#
# Epoch: 92, Avg. Training Loss: 0.006858746120706201 Avg. Validation Loss: 0.009069711887551582
#
# Epoch: 93, Batch: 10, Avg. Training Loss: 0.004207658092491328
# Epoch: 93, Batch: 20, Avg. Training Loss: 0.004453690478112548
# Epoch: 93, Batch: 30, Avg. Training Loss: 0.0066663726155335706
# Epoch: 93, Batch: 40, Avg. Training Loss: 0.008914316882146523
# Epoch: 93, Batch: 50, Avg. Training Loss: 0.010153475287370383
# Epoch: 93, Batch: 60, Avg. Training Loss: 0.009706493059638888
# Epoch: 93, Batch: 70, Avg. Training Loss: 0.009649844910018145
# Epoch: 93, Batch: 80, Avg. Training Loss: 0.009149154552142134
# Epoch: 93, Batch: 90, Avg. Training Loss: 0.008655362276153431
# Epoch: 93, Batch: 100, Avg. Training Loss: 0.008413800522685047
# Epoch: 93, Batch: 110, Avg. Training Loss: 0.008130759908817706
# Epoch: 93, Batch: 120, Avg. Training Loss: 0.008204752759775145
# Epoch: 93, Batch: 130, Avg. Training Loss: 0.00797135288146539
# Epoch: 93, Batch: 140, Avg. Training Loss: 0.0077510491628865015
# Epoch: 93, Batch: 150, Avg. Training Loss: 0.007536444170400497
# Epoch: 93, Batch: 160, Avg. Training Loss: 0.00736907891987357
# Epoch: 93, Batch: 170, Avg. Training Loss: 0.00778541836668463
# Epoch: 93, Batch: 180, Avg. Training Loss: 0.007736085409608977
# Epoch: 93, Batch: 190, Avg. Training Loss: 0.008769525229734808
# Epoch: 93, Batch: 200, Avg. Training Loss: 0.008633714487077665
# Epoch: 93, Batch: 10, Avg. Validation Loss: 0.007255138666369021
#
# Epoch: 93, Avg. Training Loss: 0.008633714487077665 Avg. Validation Loss: 0.006255467381218777
#
# Epoch: 94, Batch: 10, Avg. Training Loss: 0.00414566807448864
# Epoch: 94, Batch: 20, Avg. Training Loss: 0.003992486651986837
# Epoch: 94, Batch: 30, Avg. Training Loss: 0.004402806819416582
# Epoch: 94, Batch: 40, Avg. Training Loss: 0.004511383129283785
# Epoch: 94, Batch: 50, Avg. Training Loss: 0.006211061053909362
# Epoch: 94, Batch: 60, Avg. Training Loss: 0.006128350656945258
# Epoch: 94, Batch: 70, Avg. Training Loss: 0.006405864439771643
# Epoch: 94, Batch: 80, Avg. Training Loss: 0.00642827485280577
# Epoch: 94, Batch: 90, Avg. Training Loss: 0.006642032101646892
# Epoch: 94, Batch: 100, Avg. Training Loss: 0.006616325627546756
# Epoch: 94, Batch: 110, Avg. Training Loss: 0.006412531975233418
# Epoch: 94, Batch: 120, Avg. Training Loss: 0.006368721123241508
# Epoch: 94, Batch: 130, Avg. Training Loss: 0.006407723009872894
# Epoch: 94, Batch: 140, Avg. Training Loss: 0.006325557891146413
# Epoch: 94, Batch: 150, Avg. Training Loss: 0.006198296798393131
# Epoch: 94, Batch: 160, Avg. Training Loss: 0.0060446848088759
# Epoch: 94, Batch: 170, Avg. Training Loss: 0.00592584767488434
# Epoch: 94, Batch: 180, Avg. Training Loss: 0.005815268911990441
# Epoch: 94, Batch: 190, Avg. Training Loss: 0.005889277965271551
# Epoch: 94, Batch: 200, Avg. Training Loss: 0.005789695411222056
# Epoch: 94, Batch: 10, Avg. Validation Loss: 0.007223449880257249
#
# Epoch: 94, Avg. Training Loss: 0.005789695411222056 Avg. Validation Loss: 0.0062416875461006865
#
# Epoch: 95, Batch: 10, Avg. Training Loss: 0.004212737898342311
# Epoch: 95, Batch: 20, Avg. Training Loss: 0.00432840947760269
# Epoch: 95, Batch: 30, Avg. Training Loss: 0.004197001860787471
# Epoch: 95, Batch: 40, Avg. Training Loss: 0.0041760138235986234
# Epoch: 95, Batch: 50, Avg. Training Loss: 0.004021730250678956
# Epoch: 95, Batch: 60, Avg. Training Loss: 0.004145536466967315
# Epoch: 95, Batch: 70, Avg. Training Loss: 0.0041284792125225065
# Epoch: 95, Batch: 80, Avg. Training Loss: 0.004090156368329189
# Epoch: 95, Batch: 90, Avg. Training Loss: 0.004521172007338869
# Epoch: 95, Batch: 100, Avg. Training Loss: 0.004479205794632436
# Epoch: 95, Batch: 110, Avg. Training Loss: 0.004623573186638003
# Epoch: 95, Batch: 120, Avg. Training Loss: 0.005223761116697764
# Epoch: 95, Batch: 130, Avg. Training Loss: 0.005494922118333097
# Epoch: 95, Batch: 140, Avg. Training Loss: 0.005593001288694461
# Epoch: 95, Batch: 150, Avg. Training Loss: 0.005515030183208483
# Epoch: 95, Batch: 160, Avg. Training Loss: 0.005920272748335263
# Epoch: 95, Batch: 170, Avg. Training Loss: 0.005875827765147035
# Epoch: 95, Batch: 180, Avg. Training Loss: 0.005904484500125462
# Epoch: 95, Batch: 190, Avg. Training Loss: 0.005920681049802192
# Epoch: 95, Batch: 200, Avg. Training Loss: 0.006485110697103662
# Epoch: 95, Batch: 10, Avg. Validation Loss: 0.010037134354934096
#
# Epoch: 95, Avg. Training Loss: 0.006485110697103662 Avg. Validation Loss: 0.01492531572961632
#
# Epoch: 96, Batch: 10, Avg. Training Loss: 0.0064171258825808765
# Epoch: 96, Batch: 20, Avg. Training Loss: 0.0056405527633614835
# Epoch: 96, Batch: 30, Avg. Training Loss: 0.0055988767417147756
# Epoch: 96, Batch: 40, Avg. Training Loss: 0.005396471387939528
# Epoch: 96, Batch: 50, Avg. Training Loss: 0.005699686077423394
# Epoch: 96, Batch: 60, Avg. Training Loss: 0.005570055750043442
# Epoch: 96, Batch: 70, Avg. Training Loss: 0.005396184917273266
# Epoch: 96, Batch: 80, Avg. Training Loss: 0.005389231813023797
# Epoch: 96, Batch: 90, Avg. Training Loss: 0.005208800479562746
# Epoch: 96, Batch: 100, Avg. Training Loss: 0.005238933023065329
# Epoch: 96, Batch: 110, Avg. Training Loss: 0.005113092676567083
# Epoch: 96, Batch: 120, Avg. Training Loss: 0.0059826853180614615
# Epoch: 96, Batch: 130, Avg. Training Loss: 0.005849010312858109
# Epoch: 96, Batch: 140, Avg. Training Loss: 0.005707006627095064
# Epoch: 96, Batch: 150, Avg. Training Loss: 0.005735089962060253
# Epoch: 96, Batch: 160, Avg. Training Loss: 0.005664903210708872
# Epoch: 96, Batch: 170, Avg. Training Loss: 0.005554786490221671
# Epoch: 96, Batch: 180, Avg. Training Loss: 0.005528352419949239
# Epoch: 96, Batch: 190, Avg. Training Loss: 0.0055354458757823225
# Epoch: 96, Batch: 200, Avg. Training Loss: 0.005631115420255809
# Epoch: 96, Batch: 10, Avg. Validation Loss: 0.006578360055573285
#
# Epoch: 96, Avg. Training Loss: 0.005631115420255809 Avg. Validation Loss: 0.007009491187465542
#
# Epoch: 97, Batch: 10, Avg. Training Loss: 0.00446970434859395
# Epoch: 97, Batch: 20, Avg. Training Loss: 0.004304813302587718
# Epoch: 97, Batch: 30, Avg. Training Loss: 0.0049411913380026816
# Epoch: 97, Batch: 40, Avg. Training Loss: 0.004554476065095514
# Epoch: 97, Batch: 50, Avg. Training Loss: 0.00451613343320787
# Epoch: 97, Batch: 60, Avg. Training Loss: 0.004372774033496777
# Epoch: 97, Batch: 70, Avg. Training Loss: 0.004910317356032984
# Epoch: 97, Batch: 80, Avg. Training Loss: 0.004974821503856219
# Epoch: 97, Batch: 90, Avg. Training Loss: 0.005006202848421202
# Epoch: 97, Batch: 100, Avg. Training Loss: 0.00491831566672772
# Epoch: 97, Batch: 110, Avg. Training Loss: 0.0048478440847247815
# Epoch: 97, Batch: 120, Avg. Training Loss: 0.004762424778891726
# Epoch: 97, Batch: 130, Avg. Training Loss: 0.004707287210756195
# Epoch: 97, Batch: 140, Avg. Training Loss: 0.0048731727192976625
# Epoch: 97, Batch: 150, Avg. Training Loss: 0.004865302558367446
# Epoch: 97, Batch: 160, Avg. Training Loss: 0.00481537813757313
# Epoch: 97, Batch: 170, Avg. Training Loss: 0.004760118690319357
# Epoch: 97, Batch: 180, Avg. Training Loss: 0.004813029306630292
# Epoch: 97, Batch: 190, Avg. Training Loss: 0.004830795718896154
# Epoch: 97, Batch: 200, Avg. Training Loss: 0.004814171682810411
# Epoch: 97, Batch: 10, Avg. Validation Loss: 0.00463561739306897
#
# Epoch: 97, Avg. Training Loss: 0.004814171682810411 Avg. Validation Loss: 0.006206898100893287
#
# Epoch: 98, Batch: 10, Avg. Training Loss: 0.003983321390114725
# Epoch: 98, Batch: 20, Avg. Training Loss: 0.004491499974392354
# Epoch: 98, Batch: 30, Avg. Training Loss: 0.004238709861723085
# Epoch: 98, Batch: 40, Avg. Training Loss: 0.004357636568602174
# Epoch: 98, Batch: 50, Avg. Training Loss: 0.005060600815340877
# Epoch: 98, Batch: 60, Avg. Training Loss: 0.005544646421913058
# Epoch: 98, Batch: 70, Avg. Training Loss: 0.005422248525012816
# Epoch: 98, Batch: 80, Avg. Training Loss: 0.005323539490927942
# Epoch: 98, Batch: 90, Avg. Training Loss: 0.005739769908703036
# Epoch: 98, Batch: 100, Avg. Training Loss: 0.005571573344059289
# Epoch: 98, Batch: 110, Avg. Training Loss: 0.005487837667830966
# Epoch: 98, Batch: 120, Avg. Training Loss: 0.0054809503276677185
# Epoch: 98, Batch: 130, Avg. Training Loss: 0.0053842448056317296
# Epoch: 98, Batch: 140, Avg. Training Loss: 0.00543607012202431
# Epoch: 98, Batch: 150, Avg. Training Loss: 0.005398687625614304
# Epoch: 98, Batch: 160, Avg. Training Loss: 0.005350508687843103
# Epoch: 98, Batch: 170, Avg. Training Loss: 0.005319554479244877
# Epoch: 98, Batch: 180, Avg. Training Loss: 0.005292688127762327
# Epoch: 98, Batch: 190, Avg. Training Loss: 0.005298227360962254
# Epoch: 98, Batch: 200, Avg. Training Loss: 0.005263851606287063
# Epoch: 98, Batch: 10, Avg. Validation Loss: 0.005233510583639145
#
# Epoch: 98, Avg. Training Loss: 0.005263851606287063 Avg. Validation Loss: 0.005852292415083331
#
# Epoch: 99, Batch: 10, Avg. Training Loss: 0.004019122407771647
# Epoch: 99, Batch: 20, Avg. Training Loss: 0.006958642916288227
# Epoch: 99, Batch: 30, Avg. Training Loss: 0.006110384462711712
# Epoch: 99, Batch: 40, Avg. Training Loss: 0.006618170655565336
# Epoch: 99, Batch: 50, Avg. Training Loss: 0.00725551609415561
# Epoch: 99, Batch: 60, Avg. Training Loss: 0.00713459278534477
# Epoch: 99, Batch: 70, Avg. Training Loss: 0.0068741317239723035
# Epoch: 99, Batch: 80, Avg. Training Loss: 0.006540098169352859
# Epoch: 99, Batch: 90, Avg. Training Loss: 0.006921264699970683
# Epoch: 99, Batch: 100, Avg. Training Loss: 0.006946647570002824
# Epoch: 99, Batch: 110, Avg. Training Loss: 0.006690012877383693
# Epoch: 99, Batch: 120, Avg. Training Loss: 0.006459360705533376
# Epoch: 99, Batch: 130, Avg. Training Loss: 0.00630356258390328
# Epoch: 99, Batch: 140, Avg. Training Loss: 0.00621213404561526
# Epoch: 99, Batch: 150, Avg. Training Loss: 0.006285622152499855
# Epoch: 99, Batch: 160, Avg. Training Loss: 0.006196173491480295
# Epoch: 99, Batch: 170, Avg. Training Loss: 0.006110855968504706
# Epoch: 99, Batch: 180, Avg. Training Loss: 0.0060007443263505895
# Epoch: 99, Batch: 190, Avg. Training Loss: 0.005950080495523779
# Epoch: 99, Batch: 200, Avg. Training Loss: 0.0058243100787512955
# Epoch: 99, Batch: 10, Avg. Validation Loss: 0.008952112635597587
#
# Epoch: 99, Avg. Training Loss: 0.0058243100787512955 Avg. Validation Loss: 0.008002100950654815
#
# Epoch: 100, Batch: 10, Avg. Training Loss: 0.004023600975051523
# Epoch: 100, Batch: 20, Avg. Training Loss: 0.0058062715688720345
# Epoch: 100, Batch: 30, Avg. Training Loss: 0.005594206531532109
# Epoch: 100, Batch: 40, Avg. Training Loss: 0.005175997165497393
# Epoch: 100, Batch: 50, Avg. Training Loss: 0.004937991607002915
# Epoch: 100, Batch: 60, Avg. Training Loss: 0.005052344058640302
# Epoch: 100, Batch: 70, Avg. Training Loss: 0.005040153338839966
# Epoch: 100, Batch: 80, Avg. Training Loss: 0.004992721584858373
# Epoch: 100, Batch: 90, Avg. Training Loss: 0.005052729152763881
# Epoch: 100, Batch: 100, Avg. Training Loss: 0.005102212484925983
# Epoch: 100, Batch: 110, Avg. Training Loss: 0.005086159557950765
# Epoch: 100, Batch: 120, Avg. Training Loss: 0.005294860036034756
# Epoch: 100, Batch: 130, Avg. Training Loss: 0.005242849109121238
# Epoch: 100, Batch: 140, Avg. Training Loss: 0.005594052477473657
# Epoch: 100, Batch: 150, Avg. Training Loss: 0.0055410206861173095
# Epoch: 100, Batch: 160, Avg. Training Loss: 0.005464318848680703
# Epoch: 100, Batch: 170, Avg. Training Loss: 0.005366942516582852
# Epoch: 100, Batch: 180, Avg. Training Loss: 0.005321963899768888
# Epoch: 100, Batch: 190, Avg. Training Loss: 0.005299058729341547
# Epoch: 100, Batch: 200, Avg. Training Loss: 0.0052842142048757515
# Epoch: 100, Batch: 10, Avg. Validation Loss: 0.00632273827213794
#
# Epoch: 100, Avg. Training Loss: 0.0052842142048757515 Avg. Validation Loss: 0.006588693995795706
#
#
# ... training finished.
#
# 	Minimum validation loss so far: 0.005818.
#
# 	Validation loss of last state: 0.006589.  Saving net ...
#
# 	Elapsed time: 0 h 18 min 1 s

# %%
# Visualize the training progress by plotting training and validation loss over the number of epochs
plt.plot(train_loss_history, label='Avg. training loss')
plt.plot(valid_loss_history, label='Avg. validation loss')
plt.title('Average training and validation loss history during training')
plt.xlabel('Number of Epochs'), plt.ylabel('Avg. loss')
plt.legend(frameon=False)
plt.show()
print('Trained net model no.: {}'.format(NET_MODEL_NO))
# Out:
# Trained net model no.: 0

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again using the last state of the trained net model
test_images, test_outputs, test_gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(test_gt_pts.size())
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 68, 2])
# torch.Size([16, 68, 2])

# %%
## TODO: visualize your test output using the last state of the trained net model
# you can use the same function as before, by un-commenting the line below:
visualize_output(test_images, test_outputs, test_gt_pts)

# %%
def test_net(test_loader, model, criterion, use_cuda):

    # evaluate test loss
    with torch.no_grad():
        
        # initialize running test loss
        running_test_loss = 0.0
        
        # set model to evaluation mode
        model.eval()
        
        # evaluate on batches of test data, assumes you already have test loader
        for batch_i, data in enumerate(test_loader):
            
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten keypoint array
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to float tensors for regression loss and move to cuda if available
            if use_cuda:
                key_pts = key_pts.type(torch.FloatTensor).cuda()
                images = images.type(torch.FloatTensor).cuda()
            else:
                key_pts = key_pts.type(torch.FloatTensor)
                images = images.type(torch.FloatTensor)
            
            # forward pass to get predicted outputs
            output_pts = model(images)

            # calculate the test_batch_loss between predicted and target keypoints
            test_batch_loss = criterion(output_pts, key_pts)
            
            # convert current test_batch_loss into a scalar and add it to the avg. running_test_loss, use .item()
            running_test_loss = (running_test_loss * batch_i + test_batch_loss.item()) / (batch_i + 1)
    
        # Print overall average test loss
        print('Overall average test loss: {:.6f}\n'.format(running_test_loss))
    
    # Return overall average test lost
    return running_test_loss

# %%
# evaluate the last state of the trained net model on the test data set
test_loss = test_net(test_loader, net, criterion, use_cuda)
# Out:
# Overall average test loss: 0.006901

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model
#model_dir = 'saved_models/'
#model_name = 'keypoints_model.pt'

# after training, save your model parameters in the dir 'saved_models'
#torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**: write your answer here (double click to edit this cell)
#
# - Since this is a regression task (detecting facial features and finding their correct positions in the image) a loss function that is recommended for such tasks is likely a good choice. I have tested both MSELoss (mean squared error loss) and SmoothL1Loss criterion since both criteria are often used for regression tasks. SmoothL1Loss also incorporates a squared error term if the loss falls below a certain threshold, otherwise it uses L1 loss.
#
# - Experiments with the different net models I have tested show that SmoothL1Loss usually leads to better fits of the facial keypoints for this specific problem.
#
# - So SmoothL1Loss was the final choice due to the outcome.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: write your answer here
#
# - I have started with a rather standard CNN structures with a feature detector block consisting of 3...5 convolutional layers (3x3 kernel size, stride = 1, padding = 1) with max pooling layers (kernel size = 2x2, stride = 2) and a classifier block with 2...3 fully connected linear layers. For the models no. 0 resp. no. 1 with 3 resp. 4 convolutional layers I have increased the stride of the convolutional filter kernel to stride = 2 for the last two resp. for the last convolutional layer in order to reduce memory demand on the GPU. All convolutional and linear layers are followed by a 2d resp. 1d batch normalization layer except for the output layer. In order to prevent overfitting and to decrease the chance to get trapped in local loss minima I have added dropout layers to each layer except for the output one with constant dropout probability of 20...30% or layer-dependent dropout probability increasing from 10% for the first convolutional layer up to 30% for the last convolutional layer and the fully connected layers. I have used relu activation functions for both convolutional and linear layers. I have also tried out elu functions with small negative part (alpha = 0.1) and leaky_relu functions with small negative slope = 0.01.
#
# - Overview on the tested models:
#
# | Column 1 | Column 2 | Column 3 | Column 4 | Column 5 |
# | :------: | :------: | :------: | :------: | :------: |
# | model no. | 0 | 1 | 2 | 3 |
# | link | [model_0](model_0.py) | [model_1](model_1.py) |  [model_2](model_2.py) | [model_3](model_3.py) |
# | convolutional layers | 3 | 4 | 5 | 5 |
# | convolutional layer activation | relu | relu | relu | relu | elu |
# | linear layers | 2 | 3 | 4 | 5 | 5 |
# | linear layer activation | relu | relu | relu | relu | leaky relu |
# | min. average training loss during training | 0.004638 (epoch 91) | 0.003101 (epoch 93) | 0.003869 (epoch 74) | 0.007898 (epoch 67) |
# | min. average validation loss during training | 0.005817 (epoch 91) | 0.003398 (epoch 93) | 0.003908 (epoch 74) | 0.006551 (epoch 67) |
# | avg. training loss of last state (after 100 epochs) | 0.005284 | (epoch 93) 0.003851 | 0.003875 | 0.036391 |
# | avg. validation loss of last state (after 100 epochs) | 0.006588 | 0.003676 | 0.004382 | 0.037176 |
# | avg. test loss of last state (after 100 epochs) | 0.006901 | 0.003295 | 0.003341 | 0.029736 |
# | training time on GeForce GTX 970M GPU for 100 epochs | 18 min 1 s | 30 min 59 s | 40 min 46 s | 40 min 7 s |
#
# - I have trained all 4 model variants 100 epochs for comparision. For model_3 I have repeated the training for 500 epochs to see if there is any noticable improvements. When increasing the number of training epochs from 100 to 500 the average loss on the test dataset dropped from 0.029736 to 0.002398. The effort for improvement is now growing overproportionally to the benefit. So I stuck with 100 training epochs.
#
# - The model with elu and leaky_relu activation functions and decreasing dropout probability from first to last convolutional layer seems to have the highest potential, but also requires strong training efforts and long training times.
#
# - What concerns testing the trained detectors on the test data set the outcome is similar for the current state of training. Some facial features are not correctly detected resp. not detected in the right position as the detector misinterprets some folds in the face as eyes, for instance. In other cases predicted facial keypoints are scaled too small compared to the real face. Here we should have more training data to see further improvements on prediction quality. Most likely the deeper networks will have a the higher potential to improve when increasing the training data set.
#
# - In many cases the training process ended up in some local minimum and saturated until I found out that the learning rate scheduler I have used caused the problem. Without the learning rate scheduler, which helped me in other problems, the training process converged much better here. So the learning rate scheduler seems to be a rather disturbing element causing the optimization process be trapped at some local minimum. So I have swiched it off.
#
# - With the same weight initialization method the results vary a lot. When repeating the same initialization method several times you may end up with higher or lower loss levels at the beginning and after the training. So the starting point of the optimzation is important when training only for a low number of epochs because it determines which local minima you may catch. I have tried out four different initialization methods, but for me the standard initialization method inbuilt in pytorch (without adding anything) worked best here. When increasing the number of epochs while making use of stochasitc regularization methods like dropout the effect of the initialization becomes less important. However, if you start with a low loss due to a good initialization you have less computational effort.

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: write your answer here
#
# - As I prefer working on my local machine I am limited by my GPU memory. So I have tried to increase batch size from 10 to 20, what lead to memory issues with the larger models. So I ended up on about 16 at maximum with my final model due to cuda memory limitations. With smaller models I can increase the batch size a little further.
#
# - I have started testing with 10...20 epochs comparing different models and often ending up with being trapped in some local minimum (due to the learning rate scheduler as it turned out).
#
# - When the model and optimization parameters seemed ok for me I have increased the number of epochs up to 500 for model no. 3 with elu and leaky_relu activation functions for this was harder to train. For the other models I went for 100 epochs. During training you have quite some loss fluktuations that may show sudden spikes that can really shoot up when dropout changes parameters, but there are often quite impressive improvements, too, with much lower losses as well.
#
# - In most cases the training leads to a quick drop in loss at the very beginning, but then the loss curve just saturates at some level fluctuating with hardly any trend to lower. However, though there is hardly any reduction in loss the convolutional filters still seem to continue to evolve because the results get better.
#
# - At the beginning of the training the convolutional filters behave like some kind of blurring filters. After some more training epochs they slowly turn into some kind of corner or edge detector. So therefore I conclude that facial keypoint detection often needs a longer training time.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1[0].weight.data.cpu() # net.conv1[0] => conv2d layer | net.conv1[1] => batch_norm layer

# convert weights from tensor to numpy array
w1 = weights1.numpy()

# First layer has 32 filter kernels of size 1 x 3 x 3
filter_index = 31 # 0...31 => second index is fixed to zero as there is only one gray/color channel

print(w1[filter_index][0])
print(w1[filter_index][0].shape)

# display the filter weights
plt.imshow(w1[filter_index][0], cmap='gray')
# Out:
# [[ 0.27923605 -0.16292572  0.06719605]
#  [-0.35538712  0.17601755  0.20397078]
#  [-0.22406593  0.007781   -0.35427728]]
# (3, 3)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset

# Get random sample batch from test loader
sample_batch = next(iter(test_loader)) # returns a list of dictionaries with the keys 'image' and 'keypoints'
image = sample_batch['image'][0].data # get first image from test sample batch
#print(image.size())

# un-transform the tensor format of the sample image and convert it back to numpy image format
image = image.numpy()                    # convert tensor to numpy array
image = np.transpose(image, (1, 2, 0))   # transpose image to go from torch to numpy image format
#print(image.shape)

# Plot the selected test image
plt.figure(figsize=(10,10))
ax = plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(image), cmap='gray')
plt.title('Transformed test image')

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
w1_filtered_image = cv2.filter2D(image, -1, w1[filter_index][0])

# plot the filtered test image
ax = plt.subplot(1, 2, 2)
plt.imshow(np.squeeze(w1_filtered_image), cmap='gray')
plt.title('Transformed test image filtered with selected 1x3x3-kernel')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: (does it detect vertical lines or does it blur out noise, etc.) write your answer here
#
# - The trained filter properties seem to depend heavily on the number of training cycles resp. epochs.
#
# - When the training process is run just for a few epochs the filter coefficients still resemble their random initialization state so that the filter effect is weak. It mainly leads to blurring effects when such a kernel is applied directly on the input image.
#
# - When the training process has evolved over a larger number of epochs the filters are turned into some kind of edge or corner detectors still combined with blurring effects. But this is not always the case.
#
# - The filters of the deeper layers are more like edge detectors. However, to shape their properties takes quite a while of training.

# %%
# Plot in separate interactive figures to be able to zoom
#%matplotlib notebook
# %matplotlib inline

# %%
# Make predictions on a sample batch of images returing activations, feature maps and layer outputs of the CNN model
def net_sample_outputs_per_layer():
    
    # Switch off gradients in net model for efficient evaluation
    with torch.no_grad():
        
        # Set model to evaluation mode (switch off dropout)
        net.eval()
        
        # Get random sample batch from test loader
        sample_batch = next(iter(test_loader)) # returns a list of dictionaries with the keys 'image' and 'keypoints'
        
        # get sample data of the first image of the batch: images and ground truth keypoints
        images = sample_batch['image']
        gt_key_pts = sample_batch['keypoints']
        
        # convert images to FloatTensors and move to cuda if available
        if use_cuda:
            images = images.type(torch.FloatTensor).cuda()
        else:
            images = images.type(torch.FloatTensor)
        
        # forward pass to get net output
        output_pts, activations, feature_maps, layer_outputs = net.predict(images)
        # output_pts, feature_maps = net.predict(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # Copy tensor of images, output_pts, activations, feature_maps and layer_outputs back to CPU if they are not there yet
        images = images.cpu()
        output_pts = output_pts.detach().cpu() # detach the tensors from the model graph
        for layer in activations.keys():
            activations[layer] = activations[layer].detach().cpu()
        for layer in feature_maps.keys():
            feature_maps[layer] = feature_maps[layer].detach().cpu()
        for layer in layer_outputs.keys():
            layer_outputs[layer] = layer_outputs[layer].detach().cpu()
        
        # Return batch of images, ground truth key points, predicted keypoints, activations, feaature maps and layer outputs
        return images, output_pts, activations, feature_maps, layer_outputs, gt_key_pts

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, \
test_output_pts, \
test_activations, \
test_feature_maps, \
test_layer_outputs, \
test_gt_pts = net_sample_outputs_per_layer()
# test_images, test_output_pts, test_feature_maps, test_gt_pts = net_sample_outputs_per_layer()

# print out the dimensions of the data to see if they make sense
print('Shape of input image batch tensor: \n{}'.format(test_images.data.size()))
print('Shape of predicted keypoints batch tensor: \n{}'.format(test_output_pts.data.size()))
print('Shape of ground truth keypoints batch tensor: \n{}'.format(test_gt_pts.size()))
# Out:
# Shape of input image batch tensor:
# torch.Size([16, 1, 224, 224])
# Shape of predicted keypoints batch tensor:
# torch.Size([16, 68, 2])
# Shape of ground truth keypoints batch tensor:
# torch.Size([16, 68, 2])

# %%
# print dictionary of activations
for layer in test_activations.keys():
    print('Shape of activation tensor in layer "{}": {}'.format(layer, test_activations[layer].shape))
# Out:
# Shape of activation tensor in layer "conv1": torch.Size([16, 32, 224, 224])
# Shape of activation tensor in layer "conv2": torch.Size([16, 64, 56, 56])
# Shape of activation tensor in layer "conv3": torch.Size([16, 128, 14, 14])
# Shape of activation tensor in layer "fc1": torch.Size([16, 1024])

# %%
# print dictionary of feature maps
for layer in test_feature_maps.keys():
    print('Shape of feature maps tensor in layer "{}": {}'.format(layer, test_feature_maps[layer].shape))
# Out:
# Shape of feature maps tensor in layer "conv1": torch.Size([16, 32, 224, 224])
# Shape of feature maps tensor in layer "conv2": torch.Size([16, 64, 56, 56])
# Shape of feature maps tensor in layer "conv3": torch.Size([16, 128, 14, 14])

# %%
# print dictionary of layer outputs
for layer in test_layer_outputs.keys():
    print('Shape of layer outputs tensor in layer "{}": {}'.format(layer, test_layer_outputs[layer].shape))
# Out:
# Shape of layer outputs tensor in layer "pool_conv1": torch.Size([16, 32, 112, 112])
# Shape of layer outputs tensor in layer "pool_conv2": torch.Size([16, 64, 28, 28])
# Shape of layer outputs tensor in layer "pool_conv3": torch.Size([16, 128, 7, 7])
# Shape of layer outputs tensor in layer "fc1": torch.Size([16, 1024])

# %%
# visualize one batch of test images
visualize_output(test_images, test_output_pts, test_gt_pts, batch_size=1)

# %%
# visualize the activations of all convolutional hidden layers
# by default this shows a single-image-batch
def visualize_activations(activations, batch_size=1):

    # Loop over the batch
    for i in range(batch_size):
        
        # Loop over the activations of all hidden layers
        for layer in activations.keys():
            
            # Consider only convolutional layers
            if 'conv' in layer:
                
                # get the shape of the activations of the current convolutional layer
                #d, w, h = activations[layer][i].data.shape
                
                # un-transform the activations for each convolutional layer from tensor to numpy
                # print(activations[layer][i].data.shape)
                amaps = activations[layer][i].data # get the activations of ith layer
                amaps = amaps.numpy() # convert activations from tensor to numpy 
                amaps = np.transpose(amaps, (1, 2, 0)) # transpose to go from torch tensor to numpy image format
                activations[layer] = amaps # write un-transformed activations back to dictionary
                # print(amaps.shape)
                
                # get the shape of the activations of the current convolutional layer
                w, h, d = amaps.shape
                
                # Get optimal arrangement of the activation images for each convolutional layer in the plot
                cols = int(np.power(2, np.floor(np.log2(np.sqrt(d)))))
                rows = int(d / cols)
                
                # Initialize activations image
                amaps_image = np.zeros((h * rows, w * cols))
                
                # Loop over all activations of the current convolutional layer
                for row_idx in range(rows):
                    for col_idx in range(cols):
                        idx = row_idx * cols + col_idx
                        amaps_image[row_idx*h:(row_idx+1)*h,col_idx*w:(col_idx+1)*w] = amaps[:, :, idx]
                
                # Show all the activations of the current convolutional layer in a new single plot
                plt.figure(figsize=(20,10))
                plt.imshow(amaps_image, cmap='gray')
                plt.axis('off')
                plt.title('Activations of convolutional layer "{}" of shape w x h x d = {} x {} x {}'.format(layer,
                                                                                                         w, h, d))
    # Show all plots
    plt.show()

# %%
# Visualize the activations of all hidden layers of the net model resulting from the test image input
visualize_activations(test_activations)

# %%
# visualize the feature maps of all convolutional layers
# by default this shows a single-image-batch
def visualize_feature_maps(feature_maps, batch_size=1):

    # Loop over the batch
    for i in range(batch_size):
        
        # Loop over the feature maps of all convolutional layers
        for layer in feature_maps.keys():
                        
            # Consider only convolutional layers
            if 'conv' in layer:
                
                # get the shape of the feature maps of the current convolutional layer
                #d, w, h = feature_maps[layer][i].data.shape
                
                # un-transform the feature maps for each layer from tensor to numpy
                # print(feature_maps[layer][i].data.shape)
                fmaps = feature_maps[layer][i].data # get the feature maps of ith layer
                fmaps = fmaps.numpy() # convert feature maps from tensor to numpy 
                fmaps = np.transpose(fmaps, (1, 2, 0)) # transpose to go from torch tensor to numpy image format
                feature_maps[layer] = fmaps # write un-transformed feature maps back to dictionary
                
                # get the shape of the feature maps of the current convolutional layer
                w, h, d = fmaps.shape
                
                # Get optimal arrangement of the feature maps for each convolutional layer in the plot
                cols = int(np.power(2, np.floor(np.log2(np.sqrt(d)))))
                rows = int(d / cols)
                
                # Initialize feature maps image
                fmaps_image = np.zeros((h * rows, w * cols))
                
                # Loop over all feature maps of the current convolutional layer
                for row_idx in range(rows):
                    for col_idx in range(cols):
                        idx = row_idx * cols + col_idx
                        fmaps_image[row_idx*h:(row_idx+1)*h,col_idx*w:(col_idx+1)*w] = fmaps[:, :, idx]
            
                # Show all the feature maps of the current convolutional layer in a new single plot
                plt.figure(figsize=(20,10))
                plt.imshow(fmaps_image, cmap='gray')
                plt.axis('off')
                plt.title('Feature maps of convolutional layer "{}" of shape w x h x d = {} x {} x {}'.format(layer,
                                                                                                         w, h, d))
    # Show all plots  
    plt.show()

# %%
# Visualize the feature maps of all convolutional layers of the net model resulting from the test image input
visualize_feature_maps(test_feature_maps)

# %%
# visualize the layer outputs of all convolutional hidden layers
# by default this shows a single-image-batch
def visualize_layer_outputs(layer_outputs, batch_size=1):

    # Loop over the batch
    for i in range(batch_size):
        
        # Loop over the layer outputs of all convolutional layers
        for layer in layer_outputs.keys():
            
            # Consider only convolutional layers
            if 'conv' in layer:
                
                # get the shape of the layer outputs of the current convolutional layer
                d, w, h = layer_outputs[layer][i].data.shape
                
                # un-transform the layer outputs for each convolutional layer from tensor to numpy
                # print(layer_outputs[layer][i].data.shape)
                lomaps = layer_outputs[layer][i].data # get the layer outputs of ith layer
                lomaps = lomaps.numpy() # convert layer outputs from tensor to numpy 
                lomaps = np.transpose(lomaps, (1, 2, 0)) # transpose to go from torch tensor to numpy image format
                layer_outputs[layer] = lomaps # write un-transformed layer outputs back to dictionary
                
                # get the shape of the layer outputs of the current convolutional layer
                w, h, d = lomaps.shape
                
                # Get optimal arrangement of the layer output images for each convolutional layer in the plot
                cols = int(np.power(2, np.floor(np.log2(np.sqrt(d)))))
                rows = int(d / cols)
                
                # Initialize layer outputs image
                lomaps_image = np.zeros((h * rows, w * cols))
                
                # Loop over all layer outputs of the current convolutional layer
                for row_idx in range(rows):
                    for col_idx in range(cols):
                        idx = row_idx * cols + col_idx
                        lomaps_image[row_idx*h:(row_idx+1)*h,col_idx*w:(col_idx+1)*w] = lomaps[:, :, idx]
                
                # Show all the feature maps of the current layer in a new single plot
                plt.figure(figsize=(20,10))
                plt.imshow(lomaps_image, cmap='gray')
                plt.axis('off')
                plt.title('Layer outputs of convolutional layer "{}" of shape w x h x d = {} x {} x {}'.format(layer,
                                                                                                         w, h, d))
    # Show all plots  
    plt.show()

# %%
# Visualize the layer outputs of all convolutional layers of the net model resulting from the test image input
visualize_layer_outputs(test_layer_outputs)

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
